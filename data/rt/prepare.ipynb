# %% [markdown]
# # RealTrack data preparation
#
# This notebook prepares the RealTrack (RT) training data. `INPUT_DIR` is expected to point to the `RealTracks` directory from Band-in-a-Box UltraPAK 2018, so that each subdirectory of `INPUT_DIR` contains the WMA files for a single RealTrack.
#
# The code creates a `wav_16kHz` directory containing the 8-second training segments, a `metadata.json` file with information about each segment, and `pairs_train`, `pairs_val` and `pairs_test` files listing pairs of audio file paths. Note that `pairs_test` is not used in the paper.
#
# Copyright 2020 InterDigital R&D and Télécom Paris.
# Author: Ondřej Cífka

# %%
import argparse
import collections
import concurrent.futures as cf
import glob
import hashlib
import json
import os
import random
import regex as re
import sys

import IPython.display as ipd
import itertools
import librosa
import matplotlib.pyplot as plt
from natsort import natsorted, ns
import numpy as np
import pandas as pd
import pydub
import pysndfx
from pydub import silence
from sklearn.model_selection import train_test_split
import soundfile as sf
from tqdm.auto import tqdm

# %%
INPUT_DIR = 'RealTracks'
OUTPUT_DIR = 'wav_16kHz'

# Load data augmentation parameters from metadata_ref.json instead of sampling them randomly.
# Set to True to reproduce the dataset from the paper. Set to False if you want to use your own data.
USE_REF_METADATA = True

MAX_FINAL_CHUNK_LEN = 8000  # 8 s
MAX_TRANSPOSE = 4  # maximum number of transposition steps
MAX_RESAMPLE = 2 ** (4 / 12)
MAX_CHUNK_LEN = int(MAX_FINAL_CHUNK_LEN * MAX_RESAMPLE / 1000 + 0.5) * 1000  # 10 s
MAX_CHUNKS = 20 * 60 * 1000 // MAX_CHUNK_LEN  # 20 min
SR = 16000

# %%
def random_fx(rng):
    chain = pysndfx.AudioEffectsChain()
    for _ in range(rng.choice([0, 1, 2, 3], p=[0.35, 0.4, 0.2, 0.05])):
        effect = rng.choice([
            lambda c: c.overdrive(gain=rng.uniform(10, 40)),
            lambda c: c.phaser(gain_in=rng.uniform(0.6, 0.9),
                               gain_out=rng.uniform(0.66, 0.85),
                               delay=rng.power(0.4) * 3 + 1,
                               decay=rng.uniform(0.2, 0.45),
                               speed=rng.uniform(0.5, 2),
                               triangular=rng.choice([True, False])),
            lambda c: c.gain(-3).reverb(),
            lambda c: c.tremolo(freq=rng.power(0.5) * 14 + 1,
                                depth=rng.uniform(20, 60))
        ])
        effect(chain)
    return chain

# %%
def pydub_to_numpy(audio, sr=SR):
    samples = audio.set_channels(1).set_frame_rate(sr).get_array_of_samples()
    array = np.array(samples)
    src_dtype = array.dtype
    array = array.astype(np.float32)
    if len(samples) > 0:
        array /= np.iinfo(src_dtype).max
    return array

# %%
def process_dir(args):
    dir_path = args
    dir_name = os.path.basename(dir_path)
    out_dir = os.path.join(OUTPUT_DIR, dir_name)
    os.makedirs(out_dir)
    
    if USE_REF_METADATA:
        with open('metadata_ref.json') as f:
            metadata_ref_raw = json.load(f)
        metadata_ref = collections.OrderedDict()
        for item in metadata_ref_raw:
            if item['style'] == dir_name:
                ref_key = tuple(os.path.splitext(os.path.basename(segment['path']))[0]
                                for segment in item['segments'])
                assert ref_key not in metadata_ref
                metadata_ref[ref_key] = item
    else:
        seed = int.from_bytes(hashlib.sha512(dir_name.encode()).digest(), 'big')
        rng = np.random.default_rng(seed=seed)

    chunks = []
    for path in glob.glob(os.path.join(dir_path, '*.wma')):
        filename = os.path.basename(path)
        name, _ = os.path.splitext(filename)
        audio = pydub.AudioSegment.from_file(path)
        for t in range(0, len(audio), MAX_CHUNK_LEN):
            end = t + MAX_CHUNK_LEN
            chunks.append(argparse.Namespace(
                audio=audio, start=t, end=end,
                name=f'{name}.{t // 1000}-{end // 1000}',
                src_path=os.path.join(dir_name, filename)))
    chunks.sort(key=lambda chk: (chk.src_path, chk.name))

    if USE_REF_METADATA:
        chunks_by_name = {chk.name: chk for chk in chunks}
        chunks = [chunks_by_name[name] for key in metadata_ref for name in key]
    else:
        rng.shuffle(chunks)
        chunks = chunks[:MAX_CHUNKS]

    metadata = []
    for chunk_pair in zip(chunks[::2], chunks[1::2]):
        meta = {
            'style': dir_name
        }

        if USE_REF_METADATA:
            ref_key = tuple(chk.name for chk in chunk_pair)
            meta['resample_rate'] = metadata_ref[ref_key]['resample_rate']
            effects = pysndfx.AudioEffectsChain()
            effects.command = metadata_ref[ref_key]['effects']
        else:
            # Pick a resampling rate so as to transpose by a whole number of steps
            meta['resample_rate'] = 1 / (2 ** (rng.choice(np.arange(-MAX_TRANSPOSE, MAX_TRANSPOSE + 1)) / 12))

            # Pick random effects
            effects = random_fx(rng)
        meta['effects'] = effects.command

        meta['segments'] = []
        for chunk in chunk_pair:
            audio = pydub_to_numpy(chunk.audio[chunk.start:chunk.end])
            
            # Apply effects
            audio = librosa.resample(audio, SR, SR * meta['resample_rate'])
            audio = effects(audio, sample_in=SR)

            # Clip to maximum length
            audio = audio[:MAX_FINAL_CHUNK_LEN * SR // 1000]

            out_path = os.path.join(out_dir, f'{chunk.name}.wav')
            sf.write(out_path, audio, SR, subtype='PCM_24')
            
            meta['segments'].append({
                'src_path': chunk.src_path,
                'path': os.path.relpath(out_path, OUTPUT_DIR),
                'index': chunk.start // MAX_CHUNK_LEN
            })
        metadata.append(meta)

    return dir_name, metadata

dir_paths = sorted(set(os.path.dirname(p) for p in glob.glob(os.path.join(INPUT_DIR, '*', '*.wma'))))
metadata = []
with cf.ProcessPoolExecutor(16) as executor:
    for style, metadata_chunk in tqdm(executor.map(process_dir, dir_paths), total=len(dir_paths)):
        metadata.extend(metadata_chunk)
        print(style, 'OK')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=1526.0), HTML(value='')))
# Accordion, Rhythm EuropeanFastWaltzCory Sw 180 OK
# Accordion, Rhythm GypsyJazzCompCory Sw 220 OK
# Accordion, Rhythm GypsyWaltz Sw 200 OK
# Accordion, Rhythm ItalianTarantellaCory Sw 130 OK
# Accordion, Rhythm Klezmer44Cory Ev 130 OK
# Accordion, Rhythm KlezmerGypsyCory Sw 190 OK
# Accordion, Rhythm KlezmerHora34Cory Ev 120 OK
# Accordion, Rhythm KlezmerPolkaABCory Ev 140 OK
# Accordion, Rhythm KlezmerPopWaltz Ev 110 OK
# Accordion, Rhythm OldWorld2Beat Ev16 140 OK
# Accordion, Rhythm OldWorld2BeatHeldPlus Ev16 140 OK
# Accordion, Rhythm OldWorldWaltz Ev 180 OK
# Accordion, Rhythm OldWorldWaltzHeldPlus Ev 180 OK
# Accordion, Rhythm PasoMusette Ev 120 OK
# Accordion, Rhythm PolkaTradCory Ev 140 OK
# Accordion, Rhythm Pop8ths Ev 085 OK
# Accordion, Rhythm Pop8ths Ev 110 OK
# Accordion, Rhythm PopCalypso Ev 100 OK
# Accordion, Rhythm PopRockCory Ev 085 OK
# Accordion, Rhythm PopRockCory Ev 120 OK
# Accordion, Rhythm SpanishTango Ev 120 OK
# Accordion, Rhythm SwedishSnoaCory Ev 110 OK
# Accordion, Rhythm TangoMusette Ev 100 OK
# Accordion, Rhythm TexMex2Beat Ev 120 OK
# Accordion, Rhythm TexMexCountry Ev 120 OK
# Accordion, Rhythm ValseMusette34 Ev 165 OK
# Accordion, Rhythm ValseMusetteClassic34 Ev 165 OK
# Accordion, Soloist GypsySwingCory Sw 220 OK
# Autoharp, Rhythm OldTime Ev16 110 OK
# Autoharp, Rhythm OldTimeSlowWaltz Sw 085 OK
# Banjo, Background Backporch Ev 098 OK
# Banjo, Bluegrass Doc Ev 100 OK
# Banjo, Bluegrass Ev 130 OK
# Banjo, Clawhammer, Rhythm HipFolk Sw16 85 OK
# Banjo, Clawhammer, Rhythm OldTime Ev16 110 OK
# Banjo, Rhythm BluegrassWaltz Ev 140 OK
# Banjo, Rhythm BluegrassWaltz Sw 085 OK
# Banjo, Rhythm Folkie16ths Sw16 085 OK
# Banjo, Rhythm NorthernRockBallad Ev 065 OK
# Banjo, Rhythm, ModernCountrySync Ev16 100 OK
# Banjo, Rhythm, Pop16ths Ev 085 OK
# Banjo, Rhythm, PopCrossover Sw16 075 OK
# Banjo, Tenor, Rhythm DixielandFastA-B Sw 165 OK
# Banjo, Tenor, Rhythm DixielandMediumA-B Sw 110 OK
# Banjo, Tenor, Rhythm DixielandRazzmatazz Sw 165 OK
# Banjo, Tenor, Rhythm GypsyFolk Sw 190 OK
# Banjo, Tenor, Rhythm OldTimeCanadianJigQuinn Sw 110 OK
# Banjo, Tenor, Rhythm OldTimeCanadianReelQuinn Ev16 110 OK
# Banjo, Tenor, Rhythm OldTimeCanadianWaltzQuinn Sw 140 OK
# Banjo, Tenor, Soloist CelticReel Ev16 110 OK
# Baritone Horn, Rhythm OldWorld2Beat Ev16 140 OK
# Baritone Horn, Rhythm OldWorldWaltz Ev 180 OK
# Bass, Acoustic Bluegrass Doc Ev 100 OK
# Bass, Acoustic, AmericanaSlow128Byron Sw 040 OK
# Bass, Acoustic, AmericanaSlow16thsByron Ev16 060 OK
# Bass, Acoustic, Bluegrass Ev 130 OK
# Bass, Acoustic, BluegrassWaltz Ev 140 OK
# Bass, Acoustic, BluesyPopByron Ev 100 OK
# Bass, Acoustic, Bossa Ev 085 OK
# Bass, Acoustic, Bossa Ev 110 OK
# Bass, Acoustic, Bossa Ev 140 OK
# Bass, Acoustic, BossaFastNeil Ev 260 OK
# Bass, Acoustic, BossaRon Ev 140 OK
# Bass, Acoustic, Bowed Held Ev 085 OK
# Bass, Acoustic, Bowed Held Sw 110 OK
# Bass, Acoustic, CelticHornpipe Sw16 070 OK
# Bass, Acoustic, CelticJig Sw 110 OK
# Bass, Acoustic, CelticReel Ev16 110 OK
# Bass, Acoustic, CelticSlipJig Sw 110 OK
# Bass, Acoustic, ChaCha Ev 110 OK
# Bass, Acoustic, CountryWaltz Sw 085 OK
# Bass, Acoustic, CountryWaltz Sw 110 OK
# Bass, Acoustic, CountryWaltz Sw 140 OK
# Bass, Acoustic, FusionSlowNeil Ev 100 OK
# Bass, Acoustic, GypsyJazzBallad Sw 110 OK
# Bass, Acoustic, GypsyJazzFast Sw 250 OK
# Bass, Acoustic, GypsyJazzLatin Ev 165 OK
# Bass, Acoustic, GypsyJazzWaltz Sw 200 OK
# Bass, Acoustic, Held Ev 085 OK
# Bass, Acoustic, Held Ev 110 OK
# Bass, Acoustic, ItalianTarantellaNeil Sw 130 OK
# Bass, Acoustic, Jazz Ballad Sw 060 OK
# Bass, Acoustic, Jazz Ballad Sw 085 OK
# Bass, Acoustic, Jazz BeBop Sw 190 OK
# Bass, Acoustic, Jazz Modern Sw 140 OK
# Bass, Acoustic, Jazz Paul Sw 140 OK
# Bass, Acoustic, Jazz Ray Sw 160 OK
# Bass, Acoustic, Jazz Sw 110 OK
# Bass, Acoustic, Jazz Sw 140 OK
# Bass, Acoustic, Jazz Waltz Sw 085 OK
# Bass, Acoustic, Jazz Waltz Sw 110 OK
# Bass, Acoustic, Jazz Waltz Sw 140 OK
# Bass, Acoustic, JazzBalladRonA-B Sw 085 OK
# Bass, Acoustic, JazzBebopABNeil Sw 260 OK
# Bass, Acoustic, JazzBebopSmokinABNeil Sw 350 OK
# Bass, Acoustic, JazzSwingRonA-B Sw 140 OK
# Bass, Acoustic, JazzWaltzFastABNeil Sw 220 OK
# Bass, Acoustic, JazzWaltzRonA-B Sw 140 OK
# Bass, Acoustic, JazzWaltzSlowRonA-B Sw 085 OK
# Bass, Acoustic, Klezmer44Neil Ev 130 OK
# Bass, Acoustic, KlezmerHora34Neil Ev 120 OK
# Bass, Acoustic, KlezmerPolkaABNeil Ev 140 OK
# Bass, Acoustic, Mambo Ev 150 OK
# Bass, Acoustic, ModernJazz16thsNeil Ev 110 OK
# Bass, Acoustic, ModernJazz8thsNeil Ev 120 OK
# Bass, Acoustic, ModernJazzLatinBalladNeil Ev 110 OK
# Bass, Acoustic, ModernJazzSlowSwingNeil Sw 085 OK
# Bass, Acoustic, Pop Sw 065 OK
# Bass, Acoustic, Pop Sw 085 OK
# Bass, Acoustic, Pop Sw 120 OK
# Bass, Acoustic, Pop Sw 165 OK
# Bass, Acoustic, Pop Sw 190 OK
# Bass, Acoustic, PopWaltz Ev 085 OK
# Bass, Acoustic, RockabillyRockNRoll Ev 165 OK
# Bass, Acoustic, RockabillySlapBoomChicka Ev16 100 OK
# Bass, Acoustic, RockabillySlapSlowSwing Sw 085 OK
# Bass, Acoustic, RockabillySlowSwing Sw 085 OK
# Bass, Acoustic, RockabillySwingByron Sw 190 OK
# Bass, Acoustic, Rumba Ev 110 OK
# Bass, Acoustic, Samba Ev 190 OK
# Bass, Acoustic, SlapJive Sw 190 OK
# Bass, Acoustic, SmoothBalladNeil Ev16 065 OK
# Bass, Acoustic, SmoothCoolNeil Sw16 075 OK
# Bass, Acoustic, SmoothPoppyNeil Ev16 090 OK
# Bass, Acoustic, Soloist Bossa Ev 140 OK
# Bass, Acoustic, Soloist Jazz Sw 140 OK
# Bass, Acoustic, SpanishTangoNeil Ev 120 OK
# Bass, Acoustic, Tango Ev 100 OK
# Bass, Acoustic-Guitar, FolkSwing Sw 110 OK
# Bass, Acoustic-Guitar, FolkSwing Sw 140 OK
# Bass, Baby, Bolero Ev 090 OK
# Bass, Baby, Guajira Ev 120 OK
# Bass, Baby, Guaracha32 Ev 180 OK
# Bass, Baby, Guaracha32Push Ev 180 OK
# Bass, Baby, SonMontuno Ev 165 OK
# Bass, Baby, SonMontunoPush Ev 165 OK
# Bass, Electric CountryPopByron12-key Ev 085 OK
# Bass, Electric CountryTrainBeat12-key Ev16 090 OK
# Bass, Electric, 12-8 Crystal Sw 065 OK
# Bass, Electric, AndesHuaynoA-B Ev16 085 OK
# Bass, Electric, Blues BB Ev 085 OK
# Bass, Electric, Blues Chuck Sw 102 OK
# Bass, Electric, Blues Monday Sw 065 OK
# Bass, Electric, Blues Roadhouse Ev 120 OK
# Bass, Electric, Blues Sw 120 OK
# Bass, Electric, BluesRock Sw 140 OK
# Bass, Electric, BritInvasion Ev 120 OK
# Bass, Electric, BritInvasion Ev 140 OK
# Bass, Electric, ClassicFunkRootFiveAlex Ev 130 OK
# Bass, Electric, Country DoubleTime Ev 088 OK
# Bass, Electric, Country Ev 065 OK
# Bass, Electric, CountryBoogieA-B Sw 110 OK
# Bass, Electric, CountryBoogieA-B Sw 140 OK
# Bass, Electric, CountryDrivin8thsA-B Ev 150 OK
# Bass, Electric, CountrySwing Sw 085 OK
# Bass, Electric, CountrySwing Sw 110 OK
# Bass, Electric, ElecRock Ev 120 OK
# Bass, Electric, Folkie16ths Sw16 085 OK
# Bass, Electric, Funk James Finger Ev 100 OK
# Bass, Electric, Funk James FingerSlap Ev 100 OK
# Bass, Electric, Funk James Slap Ev 100 OK
# Bass, Electric, Funk Smooth Jammin Ev 100 OK
# Bass, Electric, FunkHalfNotePulse Ev 100 OK
# Bass, Electric, FunkHalfNotePulseSync Ev16 100 OK
# Bass, Electric, FunkPumping16ths Ev 100 OK
# Bass, Electric, FunkPumpingOffbeat8ths Ev 100 OK
# Bass, Electric, FunkPumpingQuarters Ev 100 OK
# Bass, Electric, FunkSwing16ths Sw16 085 OK
# Bass, Electric, FunkyGroove60s Ev 100 OK
# Bass, Electric, HardRockLA Ev 120 OK
# Bass, Electric, HardRockThrash Ev 085 OK
# Bass, Electric, HardRockWaltz Ev 140 OK
# Bass, Electric, JazzFunkBreezy Ev16 075 OK
# Bass, Electric, JazzFunkGroovin Ev16 110 OK
# Bass, Electric, JazzFunkMovin Ev16 130 OK
# Bass, Electric, JazzFunkPoppy Ev16 110 OK
# Bass, Electric, Metal Ev 085 OK
# Bass, Electric, Metal Ev 120 OK
# Bass, Electric, Metal Ev 165 OK
# Bass, Electric, ModernCountrySync Ev16 100 OK
# Bass, Electric, ModernDiscoFunkAlex Ev 110 OK
# Bass, Electric, ModernRnBRock Ev 065 OK
# Bass, Electric, ModernSlapFunkAlex Ev16 110 OK
# Bass, Electric, MotownFunkyTriplets Sw 120 OK
# Bass, Electric, MotownRnBUptempo Ev 165 OK
# Bass, Electric, NewOrleansBoogie Ev 165 OK
# Bass, Electric, NewOrleansMardiGras Ev16 085 OK
# Bass, Electric, NewOrleansShuffle Sw 130 OK
# Bass, Electric, NewOrleansSwinginPop Sw130 OK
# Bass, Electric, NorthernRock Sw16 075 OK
# Bass, Electric, NorthernRockBallad Ev 065 OK
# Bass, Electric, PeruFestejo68 Sw 120 OK
# Bass, Electric, PeruValsCriollo Ev 140 OK
# Bass, Electric, Pop HalfNotes Ev 085 OK
# Bass, Electric, Pop HalfNotes Ev 120 OK
# Bass, Electric, Pop HalfNotes Ev 165 OK
# Bass, Electric, Pop Sw 065 OK
# Bass, Electric, Pop Sw 085 OK
# Bass, Electric, Pop Sw 120 OK
# Bass, Electric, Pop Sw 165 OK
# Bass, Electric, Pop Sw 190 OK
# Bass, Electric, Pop Syncopated Ev 136 OK
# Bass, Electric, Pop16ths Ev 065 OK
# Bass, Electric, Pop16ths Ev 085 OK
# Bass, Electric, Pop16ths Ev 110 OK
# Bass, Electric, PopBelieve Ev16 065 OK
# Bass, Electric, PopCalypso Ev 100 OK
# Bass, Electric, PopCrossover Sw16 075 OK
# Bass, Electric, PopHalfNotesPush Ev 085 OK
# Bass, Electric, PopHalfNotesPush Ev 120 OK
# Bass, Electric, PopHalfNotesSync Ev 085 OK
# Bass, Electric, PopHalfNotesSync Ev 120 OK
# Bass, Electric, PopModernGrooveA-B Ev16 075 OK
# Bass, Electric, PopPowerA-B Ev 120 OK
# Bass, Electric, PopRockWaltz Ev 140 OK
# Bass, Electric, PopShiningA-B Ev 120 OK
# Bass, Electric, PopSw16RootFive Sw16 075 OK
# Bass, Electric, PopSw16Sync Sw16 075 OK
# Bass, Electric, PopUplift Ev16 120 OK
# Bass, Electric, PopWaltz Ev 120 OK
# Bass, Electric, PopWaltz Ev 180 OK
# Bass, Electric, PraiseBreakA-B Ev 140 OK
# Bass, Electric, PuertoRicoAguinaldo Ev16 120 OK
# Bass, Electric, PunkFuzzPickedA-B Ev 165 OK
# Bass, Electric, Reggae Ev16 100 OK
# Bass, Electric, ReggaeSlow Sw 075 OK
# Bass, Electric, RockHeavy16thsDoug Ev16 090 OK
# Bass, Electric, RockHeavy8thsDoug Ev 120 OK
# Bass, Electric, RockNRollBritSwingA-B Sw 140 OK
# Bass, Electric, RockPickedA-B Ev 165 OK
# Bass, Electric, RockShuffleHardDoug Sw 120 OK
# Bass, Electric, RootsRock Ev 100 OK
# Bass, Electric, SmoothBallad Ev16 065 OK
# Bass, Electric, SmoothCool Sw16 075 OK
# Bass, Electric, SmoothCool Sw16 100 OK
# Bass, Electric, SmoothPoppy Ev16 090 OK
# Bass, Electric, Soul60sA-B Ev 110 OK
# Bass, Electric, Soul70sA-B Ev16 100 OK
# Bass, Electric, SoulFunkSwingAlex Sw 120 OK
# Bass, Electric, SouthernRock Ev16 085 OK
# Bass, Electric, SurfRock8ths Ev 165 OK
# Bass, Electric, SurfRockSyncVintage Ev 165 OK
# Bass, Electric, TexMex2Beat Ev 120 OK
# Bass, Electric, TexMexCountry Ev 120 OK
# Bass, Electric, TexasBluesRockFunky Ev16 090 OK
# Bass, Electric, TexasBluesRockNRoll Ev 165 OK
# Bass, Electric, TexasBluesRockShuffle Sw 130 OK
# Bass, Electric, TexasBluesRockSlow12-8 Sw 060 OK
# Bass, Electric, TexasBluesRockStraight Ev 120 OK
# Bass, Electric, TexasRock Ev 120 OK
# Bass, Electric, UptempoSoul16ths Ev16 100 OK
# Bass, Fretless Electric Pop8thsRene Ev 085 OK
# Bass, Fretless Electric Rock8thsRene Ev 120 OK
# Bass, Fretless Electric Slow12-8Rene Sw 065 OK
# Bass, Fretless Electric, JazzFunkMovin Ev16 130 OK
# Bass, Synth ModernDancePop8ths Ev 120 OK
# Bass, Synth ModernDancePopSync Ev 120 OK
# Bass, Synth, AltHipHopA-B Ev16 085 OK
# Bass, Synth, CloudRapSub Ev16 075 OK
# Bass, Synth, DanceRockBuzzBassWholeSyncA-B Ev 120 OK
# Bass, Synth, DancehallAB Ev16 085 OK
# Bass, Synth, DiscoOctavesA-B Ev 120 OK
# Bass, Synth, PepSquad Ev 165 OK
# Bass, Synth, RetroPop Ev16 085 OK
# Bass, Synth, Rhythm JazzFunkFat Ev 110 OK
# Bass, Synth, RnBModernSub Ev16 065 OK
# Bass, Synth, RnBModernSub Ev16 100 OK
# Bass, Synth, TropicalHouseA-B Ev 120 OK
# Bouzouki, Rhythm CelticHornpipe Sw16 070 OK
# Bouzouki, Rhythm CelticJig Sw 110 OK
# Bouzouki, Rhythm CelticReel Ev16 110 OK
# Bouzouki, Rhythm CelticSlipJig Sw 110 OK
# Bouzouki, Rhythm CountryCrossover Sw16 075 OK
# Bouzouki, Rhythm CountryPop Ev 085 OK
# Bouzouki, Rhythm ModernCountry Ev16 075 OK
# Bouzouki, Rhythm Rock Ev 120 OK
# Bouzouki, Rhythm SlowCountrySwing Sw 085 OK
# Bouzouki, Rhythm SlowPop Ev16 065 OK
# Bouzouki, Rhythm SlowWaltz Ev 100 OK
# Cello, Background PopCountry Ev 085 OK
# Cello, Background PopEven Ev 120 (1TrackStringQuartet) OK
# Cello, Background PopSwing Sw 110 (1TrackStringQuartet) OK
# Cello, Background SlowSwing Sw 065 OK
# Cello, Background SlowWaltz Sw 085 OK
# Charango, Rhythm AndesHuayno Ev16 085 OK
# Clarinet, Background MelodicOldWorld2Beat Ev16 140 (1TrackHornSection) OK
# Clarinet, Background MelodicOldWorldWaltz Ev 180 (1TrackHornSection) OK
# Clarinet, Soloist DixielandFastA-B Sw 165 OK
# Clarinet, Soloist DixielandMediumA-B Sw 110 OK
# Clarinet, Soloist Older Swing Sw 140 OK
# Cuatro, Rhythm PuertoRicoAguinaldo Ev16 120 OK
# Fiddle, Background Allis Ev 120 OK
# Fiddle, Background AmericanaSlow128Andy Sw 040 OK
# Fiddle, Background AmericanaSlow16thsAndy Ev16 060 OK
# Fiddle, Background BluegrassWaltz Ev 140 OK
# Fiddle, Background CountryBoogie Sw 110 OK
# Fiddle, Background CountryBoogie Sw 140 OK
# Fiddle, Background CountryDrivin8ths Ev 150 OK
# Fiddle, Background CountrySwing Sw 085 OK
# Fiddle, Background CountrySwing Sw 110 OK
# Fiddle, Background CountrySwingA-B Sw 140 OK
# Fiddle, Background CountryWaltz Sw 085 OK
# Fiddle, Background CountryWaltz Sw 110 OK
# Fiddle, Background George Ev 085 OK
# Fiddle, Background MemphisSwing Sw 190 OK
# Fiddle, Background Pop16ths Ev 065 OK
# Fiddle, Background Pop16ths Ev 085 OK
# Fiddle, Background Pop16ths Ev 110 OK
# Fiddle, Background Pop8ths Ev 110 OK
# Fiddle, Background PopWaltz Ev 120 OK
# Fiddle, Background PopWaltz Ev 180 OK
# Fiddle, Background Train Ev 130 OK
# Fiddle, Background WesternSwing Sw 165 OK
# Fiddle, Background WesternSwing Sw 190 OK
# Fiddle, Rhythm Bluegrass Doc Ev 100 OK
# Fiddle, Rhythm Bluegrass Ev 130 OK
# Fiddle, Soloist Bluegrass Doc Ev 100 OK
# Fiddle, Soloist Bluegrass Ev 130 OK
# Fiddle, Soloist CelticReelAndy Ev16 110 OK
# Fiddle, Soloist CountryAndy Ev 065 OK
# Fiddle, Soloist CountryAndy Ev 165 OK
# Fiddle, Soloist CountryRob Ev 120 OK
# Fiddle, Soloist CountryShuffleRob Sw 120 OK
# Fiddle, Soloist CountryWaltzAndy Sw 085 OK
# Fiddle, Soloist CountryWorkinRob Ev16 090 OK
# Fiddle, Soloist George Ev 085 OK
# Fiddle, Soloist GypsyJazzBallad Sw 110 OK
# Fiddle, Soloist GypsyJazzFast Sw 220 OK
# Fiddle, Soloist GypsyJazzLatin Ev 165 OK
# Fiddle, Soloist GypsyJazzWaltz Sw 200 OK
# Fiddle, Soloist Train Ev 130 OK
# Fiddle, Soloist WesternSwingAndy Sw 165 OK
# Flugelhorn, Background CroonerBalladHigh Sw 060 (1TrackHornSection) OK
# Flugelhorn, Background CroonerBalladLow Sw 060 (1TrackHornSection) OK
# Flugelhorn, Background CroonerBalladMed Sw 060 (1TrackHornSection) OK
# Flute, Background CroonerBallad Sw 060 (1TrackHornSection) OK
# Flute, Background CroonerBigBand Sw 110 (1TrackHornSection) OK
# Flute, Background CroonerBossa Ev 110 (1TrackHornSection) OK
# Flute, Soloist Bossa Ev 140 OK
# Flute, Soloist JazzSwingJack Sw 140 OK
# Guitar, 12-String Acoustic, Fingerpicking Ev 085 OK
# Guitar, 12-String Acoustic, Fingerpicking Ev 120 OK
# Guitar, 12-String Acoustic, Fingerpicking Ev 165 OK
# Guitar, 12-String Acoustic, Rhythm ClassicRockA-B Ev16 065 OK
# Guitar, 12-String Acoustic, Rhythm FolkRock Ev 100 OK
# Guitar, 12-String Acoustic, Rhythm FolkRock Ev16 065 OK
# Guitar, 12-String Acoustic, Rhythm RockWaltzA-B Ev 140 OK
# Guitar, 12-String Acoustic, Strumming Ev 085 OK
# Guitar, 12-String Acoustic, Strumming Ev 120 OK
# Guitar, 12-String Acoustic, Strumming Ev 165 OK
# Guitar, 12-String Acoustic, Strumming FolkRockWaltz Ev 150 OK
# Guitar, 12-String Electric, Fingerpicking Ev 085 OK
# Guitar, 12-String Electric, Fingerpicking Ev 120 OK
# Guitar, 12-String Electric, Fingerpicking Ev 165 OK
# Guitar, 12-String Electric, Strumming Ev 085 OK
# Guitar, 12-String Electric, Strumming Ev 120 OK
# Guitar, 12-String Electric, Strumming Ev 165 OK
# Guitar, Acoustic, Background Bolero Ev 090 OK
# Guitar, Acoustic, Fingerpicking BluegrassWaltz Ev 140 OK
# Guitar, Acoustic, Fingerpicking BoomChickHighJoe Ev16 110 OK
# Guitar, Acoustic, Fingerpicking BoomChickJoe Ev16 110 OK
# Guitar, Acoustic, Fingerpicking BoomChickSlowHighJoe Sw16 085 OK
# Guitar, Acoustic, Fingerpicking BoomChickSlowJoe Sw16 085 OK
# Guitar, Acoustic, Fingerpicking CelticAir Ev 085 OK
# Guitar, Acoustic, Fingerpicking CelticSlowWaltz Ev 110 OK
# Guitar, Acoustic, Fingerpicking Country Waltz Sw 085 OK
# Guitar, Acoustic, Fingerpicking Country Waltz Sw 110 OK
# Guitar, Acoustic, Fingerpicking Country Waltz Sw 140 OK
# Guitar, Acoustic, Fingerpicking CountryBrent Ev 065 OK
# Guitar, Acoustic, Fingerpicking CountryBrent Ev 085 OK
# Guitar, Acoustic, Fingerpicking CountryBrent Ev 120 OK
# Guitar, Acoustic, Fingerpicking CountryBrent Sw 065 OK
# Guitar, Acoustic, Fingerpicking CountryBrent Sw 085 OK
# Guitar, Acoustic, Fingerpicking CountryBrent Sw 120 OK
# Guitar, Acoustic, Fingerpicking CountryWaltzBrent Sw 085 OK
# Guitar, Acoustic, Fingerpicking CountryWaltzBrent Sw 110 OK
# Guitar, Acoustic, Fingerpicking CountryWaltzBrent Sw 140 OK
# Guitar, Acoustic, Fingerpicking Ev 065 OK
# Guitar, Acoustic, Fingerpicking Ev 085 OK
# Guitar, Acoustic, Fingerpicking Ev 120 OK
# Guitar, Acoustic, Fingerpicking Ev 165 OK
# Guitar, Acoustic, Fingerpicking Ev 190 OK
# Guitar, Acoustic, Fingerpicking FolkWaltzFintan Ev 100 OK
# Guitar, Acoustic, Fingerpicking Folky16thsBrent Ev16 085 OK
# Guitar, Acoustic, Fingerpicking FolkySwing Sw 110 OK
# Guitar, Acoustic, Fingerpicking Hank Sw 065 OK
# Guitar, Acoustic, Fingerpicking Hank Sw 085 OK
# Guitar, Acoustic, Fingerpicking Hank Sw 120 OK
# Guitar, Acoustic, Fingerpicking Hank Sw 165 OK
# Guitar, Acoustic, Fingerpicking Hank Sw 190 OK
# Guitar, Acoustic, Fingerpicking HipFolk Sw16 85 OK
# Guitar, Acoustic, Fingerpicking NashvilleSwingHighJoe Sw 090 OK
# Guitar, Acoustic, Fingerpicking NashvilleSwingJoe Sw 090 OK
# Guitar, Acoustic, Fingerpicking Pop8thsSteady Ev 065 OK
# Guitar, Acoustic, Fingerpicking PopWaltz Ev 120 OK
# Guitar, Acoustic, Fingerpicking Songwriter16ths Ev16 075 OK
# Guitar, Acoustic, Fingerpicking Songwriter16thsHigh Ev16 075 OK
# Guitar, Acoustic, Fingerpicking SongwriterAlternating8thsQuinn Ev 065 OK
# Guitar, Acoustic, Fingerpicking SongwriterAlternating8thsQuinn Ev 110 OK
# Guitar, Acoustic, Fingerpicking SongwriterFolkAltBassQuinn Ev16 085 OK
# Guitar, Acoustic, Fingerpicking SongwriterFolkSlapQuinn Ev 120 OK
# Guitar, Acoustic, Fingerpicking WaltzJoe Sw 085 OK
# Guitar, Acoustic, Fingerpicking WaltzJoeHigh Sw 085 OK
# Guitar, Acoustic, Rhythm Blues12-8Brent Sw 065 OK
# Guitar, Acoustic, Rhythm BluesFunkySwBrent Sw16 075 OK
# Guitar, Acoustic, Rhythm BluesShuffleBrent Sw 130 OK
# Guitar, Acoustic, Rhythm BluesSlowSwingColin Sw 085 OK
# Guitar, Acoustic, Rhythm BluesStraightBrent Ev 085 OK
# Guitar, Acoustic, Rhythm BluesSw16GrooveBrent Sw16 085 OK
# Guitar, Acoustic, Rhythm Bolero Ev 090 OK
# Guitar, Acoustic, Rhythm CelticHornpipe Sw16 070 OK
# Guitar, Acoustic, Rhythm CelticJig Sw 110 OK
# Guitar, Acoustic, Rhythm CelticPolkaFastReelQuinn Ev16 140 OK
# Guitar, Acoustic, Rhythm CelticReel Ev16 110 OK
# Guitar, Acoustic, Rhythm CelticSlideFastJigQuinn Sw 140 OK
# Guitar, Acoustic, Rhythm CelticSlipjig Sw 110 OK
# Guitar, Acoustic, Rhythm CountryBoogieA-B Sw 110 OK
# Guitar, Acoustic, Rhythm CountryBoogieA-B Sw 140 OK
# Guitar, Acoustic, Rhythm CountryFolk8thsBrent Ev 085 OK
# Guitar, Acoustic, Rhythm CountryFolkSlowSwingBrent Sw 085 OK
# Guitar, Acoustic, Rhythm DixielandFast Sw 165 OK
# Guitar, Acoustic, Rhythm DixielandMedium Sw 110 OK
# Guitar, Acoustic, Rhythm EZListening Sw 085 OK
# Guitar, Acoustic, Rhythm EZListening Sw 140 OK
# Guitar, Acoustic, Rhythm EuropeanFastWaltzQuinn Sw 180 OK
# Guitar, Acoustic, Rhythm EuropeanFolkWaltzQuinn Sw 140 OK
# Guitar, Acoustic, Rhythm Fast4toBarQuinn Ev 140 OK
# Guitar, Acoustic, Rhythm FolkBluesSlowShuffleBrent Sw 085 OK
# Guitar, Acoustic, Rhythm FolkPulse8thsFintan Ev 110 OK
# Guitar, Acoustic, Rhythm FolkRock8thsBrent Ev 100 OK
# Guitar, Acoustic, Rhythm FolkSlowSw16Brent Sw16 060 OK
# Guitar, Acoustic, Rhythm FolkSorrow Ev16 090 OK
# Guitar, Acoustic, Rhythm Folkie16ths Sw16 085 OK
# Guitar, Acoustic, Rhythm Folky68Brent Sw 050 OK
# Guitar, Acoustic, Rhythm FolkySync8thsFintan Ev 140 OK
# Guitar, Acoustic, Rhythm FunkyFolk Ev16 110 OK
# Guitar, Acoustic, Rhythm GroovinFolk Ev 085 OK
# Guitar, Acoustic, Rhythm GroovinFolk Sw16 085 OK
# Guitar, Acoustic, Rhythm GypsyClassicQuinn Sw 220 OK
# Guitar, Acoustic, Rhythm GypsyFolk Sw 190 OK
# Guitar, Acoustic, Rhythm GypsyJazzBalladGonzalo Sw 110 OK
# Guitar, Acoustic, Rhythm GypsyJazzBalladJohn Sw 110 OK
# Guitar, Acoustic, Rhythm GypsyJazzFastGonzalo Sw 220 OK
# Guitar, Acoustic, Rhythm GypsyJazzFastJohn Sw 250 OK
# Guitar, Acoustic, Rhythm GypsyJazzLatinGonzalo Ev 165 OK
# Guitar, Acoustic, Rhythm GypsyJazzLatinJohn Ev 165 OK
# Guitar, Acoustic, Rhythm GypsyJazzWaltzGonzalo Sw 200 OK
# Guitar, Acoustic, Rhythm GypsyJazzWaltzJohn Sw 200 OK
# Guitar, Acoustic, Rhythm ItalianTarantellaQuinn Sw 130 OK
# Guitar, Acoustic, Rhythm Jazz Ballad Freddie Sw 085 OK
# Guitar, Acoustic, Rhythm Jazz Freddie Sw 140 OK
# Guitar, Acoustic, Rhythm JazzBalladFreddie Sw 060 OK
# Guitar, Acoustic, Rhythm JazzFreddie Sw 110 OK
# Guitar, Acoustic, Rhythm JazzSwingFreddie Sw 190 OK
# Guitar, Acoustic, Rhythm JazzWaltzFreddie Sw 085 OK
# Guitar, Acoustic, Rhythm JazzWaltzFreddie Sw 110 OK
# Guitar, Acoustic, Rhythm Klezmer44Quinn Ev 130 OK
# Guitar, Acoustic, Rhythm KlezmerHora34Quinn Ev 120 OK
# Guitar, Acoustic, Rhythm KlezmerPolkaABQuinn Ev 140 OK
# Guitar, Acoustic, Rhythm Muted16thsFintan Ev16 080 OK
# Guitar, Acoustic, Rhythm NorthernRockBallad Ev 065 OK
# Guitar, Acoustic, Rhythm OldTime Ev16 110 OK
# Guitar, Acoustic, Rhythm OldTimeCanadianJigQuinn Sw 110 OK
# Guitar, Acoustic, Rhythm OldTimeCanadianReelQuinn Ev16 110 OK
# Guitar, Acoustic, Rhythm OldTimeCanadianWaltzQuinn Sw 140 OK
# Guitar, Acoustic, Rhythm OldWorld2Beat Ev16 140 OK
# Guitar, Acoustic, Rhythm OldWorldWaltz Ev 180 OK
# Guitar, Acoustic, Rhythm Pop16thsJoe Ev16 110 OK
# Guitar, Acoustic, Rhythm Pop16thsSyncBrent Ev16 085 OK
# Guitar, Acoustic, Rhythm PopCalypso Ev 100 OK
# Guitar, Acoustic, Rhythm PopFunkyJoe Ev16 110 OK
# Guitar, Acoustic, Rhythm PopModernGroove Ev16 075 OK
# Guitar, Acoustic, Rhythm PopPromise Ev16 100 OK
# Guitar, Acoustic, Rhythm RagtimeBluesColin Sw 190 OK
# Guitar, Acoustic, Rhythm RnBPop8thsJoe Ev 110 OK
# Guitar, Acoustic, Rhythm SonMontuno Ev 165 OK
# Guitar, Acoustic, Rhythm Songwriter8thsBrent Ev 085 OK
# Guitar, Acoustic, Rhythm SongwriterSwingBalladBrent Sw16 065 OK
# Guitar, Acoustic, Rhythm SongwriterSwingColin Sw 075 OK
# Guitar, Acoustic, Rhythm SouthernRock Ev 085 OK
# Guitar, Acoustic, Rhythm SwampyFunkJoe Ev16 110 OK
# Guitar, Acoustic, Rhythm SwedishSchottisQuinn Ev 100 OK
# Guitar, Acoustic, Rhythm SwedishSnoaQuinn Ev 110 OK
# Guitar, Acoustic, Rhythm TrainBluesColin Ev16 090 OK
# Guitar, Acoustic, Rhythm TrainFunkyJoe Ev16 130 OK
# Guitar, Acoustic, Soloist Bluegrass Doc Ev 100 OK
# Guitar, Acoustic, Soloist Bluegrass Ev 130 OK
# Guitar, Acoustic, Soloist DixielandFast Sw 165 OK
# Guitar, Acoustic, Soloist DixielandMedium Sw 110 OK
# Guitar, Acoustic, Soloist GypsyJazzBalladGonzalo Sw 110 OK
# Guitar, Acoustic, Soloist GypsyJazzBalladJohn Sw 110 OK
# Guitar, Acoustic, Soloist GypsyJazzFastGonzalo Sw 220 OK
# Guitar, Acoustic, Soloist GypsyJazzFastJohn Sw 220 OK
# Guitar, Acoustic, Soloist GypsyJazzLatinGonzalo Ev 165 OK
# Guitar, Acoustic, Soloist GypsyJazzQuinn Sw 190 OK
# Guitar, Acoustic, Soloist GypsyJazzWaltzGonzalo Sw 200 OK
# Guitar, Acoustic, Soloist GypsyJazzWaltzJohn Sw 200 OK
# Guitar, Acoustic, Soloist JazzFunkBreezy Ev16 075 OK
# Guitar, Acoustic, Soloist SambaFusionCarlos Ev 190 OK
# Guitar, Acoustic, Strumming AcRockBright Ev 120 OK
# Guitar, Acoustic, Strumming Bluegrass Doc Ev 100 OK
# Guitar, Acoustic, Strumming Bluegrass Ev 130 OK
# Guitar, Acoustic, Strumming BluegrassWaltz Ev 140 OK
# Guitar, Acoustic, Strumming Country Waltz Sw 085 OK
# Guitar, Acoustic, Strumming Country Waltz Sw 110 OK
# Guitar, Acoustic, Strumming Country Waltz Sw 140 OK
# Guitar, Acoustic, Strumming CrossoverSnappy Sw16 090 OK
# Guitar, Acoustic, Strumming DoubleTime Ev 088 OK
# Guitar, Acoustic, Strumming Ev 065 OK
# Guitar, Acoustic, Strumming Ev 085 OK
# Guitar, Acoustic, Strumming Ev 120 OK
# Guitar, Acoustic, Strumming Ev 136 OK
# Guitar, Acoustic, Strumming Ev 165 OK
# Guitar, Acoustic, Strumming Ev 190 OK
# Guitar, Acoustic, Strumming FolkRockBritEighths Ev 085 OK
# Guitar, Acoustic, Strumming FolkRockWaltz Ev 150 OK
# Guitar, Acoustic, Strumming Hank Sw 065 OK
# Guitar, Acoustic, Strumming Hank Sw 085 OK
# Guitar, Acoustic, Strumming Hank Sw 120 OK
# Guitar, Acoustic, Strumming Hank Sw 165 OK
# Guitar, Acoustic, Strumming Hank Sw 190 OK
# Guitar, Acoustic, Strumming ModernCountrySync Ev 100 OK
# Guitar, Acoustic, Strumming Pop16ths Ev16 065 OK
# Guitar, Acoustic, Strumming Pop16ths Ev16 085 OK
# Guitar, Acoustic, Strumming Pop16ths Ev16 110 OK
# Guitar, Acoustic, Strumming PopWaltz Ev 120 OK
# Guitar, Acoustic, Strumming PopWaltz Ev 180 OK
# Guitar, Acoustic, Strumming Rascal Sw 075 OK
# Guitar, Acoustic, Strumming Spirited Ev 065 OK
# Guitar, Acoustic, Strumming Spirited Ev 085 OK
# Guitar, Acoustic, Strumming Syncopated Sugar Ev 102 OK
# Guitar, Baritone Electric, Background FastBoogieBrent Sw 190 OK
# Guitar, Baritone Electric, Background PopCountryBrent Ev 085 OK
# Guitar, Baritone Electric, Background SpaghettiWestern Ev 065 OK
# Guitar, Baritone Electric, Rhythm BluesBoogieBassAndLicks Ev 100 OK
# Guitar, Baritone Electric, Rhythm BluesShuffleBassAndLicks Sw 085 OK
# Guitar, Baritone Electric, Rhythm BoomChickaRootFiveBrent Ev16 100 OK
# Guitar, Baritone Electric, Rhythm PopCountryBrent Ev 120 OK
# Guitar, Baritone Electric, Soloist CountryWorkinBrent Ev16 100 OK
# Guitar, Electric, Background Dreamy Ev 065 OK
# Guitar, Electric, Background DreamyPopBalladFillsBrent Ev 085 OK
# Guitar, Electric, Background FunkSingleNoteWah Ev16 100 OK
# Guitar, Electric, Background, PopDreamyBrent Ev 085 OK
# Guitar, Electric, BackgroundSoloist SurfRock16thsBrent Ev 165 OK
# Guitar, Electric, Chet Comp Ev 130 OK
# Guitar, Electric, Chet Pickin' Ev 100 OK
# Guitar, Electric, Rhythm AltCountryMoody Ev 075 OK
# Guitar, Electric, Rhythm AltCountryRootsy Ev 075 OK
# Guitar, Electric, Rhythm AmericanaGrittySlow128Brent Sw 040 OK
# Guitar, Electric, Rhythm AmericanaSlow16thsBrent Ev16 060 OK
# Guitar, Electric, Rhythm AmericanaSparseSlow16thsColin Ev16 060 OK
# Guitar, Electric, Rhythm AmericanaTremoloSlow128Colin Sw 040 OK
# Guitar, Electric, Rhythm Blues BB Ev 085 OK
# Guitar, Electric, Rhythm Blues Chuck Sw 102 OK
# Guitar, Electric, Rhythm Blues Monday Sw 065 OK
# Guitar, Electric, Rhythm Blues Roadhouse Ev 120 OK
# Guitar, Electric, Rhythm Blues Sw 120 OK
# Guitar, Electric, Rhythm BluesRockCrispA-B Sw 140 OK
# Guitar, Electric, Rhythm BluesRockFuzzy Sw 140 OK
# Guitar, Electric, Rhythm Bossa Ev 140 OK
# Guitar, Electric, Rhythm BossaCompOlly12-key Ev 110 OK
# Guitar, Electric, Rhythm BossaFreeComp Ev 085 OK
# Guitar, Electric, Rhythm BossaFreeComp Ev 110 OK
# Guitar, Electric, Rhythm BossaGrooveComp Ev 110 OK
# Guitar, Electric, Rhythm BrightBluesyPopColin Ev 100 OK
# Guitar, Electric, Rhythm Country Cowboy Ev 165 OK
# Guitar, Electric, Rhythm Country Waltz Sw 110 OK
# Guitar, Electric, Rhythm CountryBluesRock Ev 110 OK
# Guitar, Electric, Rhythm CountryBluesRockHigh Ev 110 OK
# Guitar, Electric, Rhythm CountryBoogieCleanA-B Sw 110 OK
# Guitar, Electric, Rhythm CountryBoogieCleanA-B Sw 140 OK
# Guitar, Electric, Rhythm CountryBoogieGrittyA-B Sw 110 OK
# Guitar, Electric, Rhythm CountryBoogieGrittyA-B Sw 140 OK
# Guitar, Electric, Rhythm CountryDrivin8ths Ev 150 OK
# Guitar, Electric, Rhythm CountryPopBrent12-key Ev 085 OK
# Guitar, Electric, Rhythm CountryRockPopping Ev 120 OK
# Guitar, Electric, Rhythm CountryRockRiff Ev 120 OK
# Guitar, Electric, Rhythm CountrySwingCleanA-B Sw 085 OK
# Guitar, Electric, Rhythm CountrySwingCleanA-B Sw 110 OK
# Guitar, Electric, Rhythm CountrySwingCleanA-B Sw 140 OK
# Guitar, Electric, Rhythm CountrySwingGrittyA-B Sw 085 OK
# Guitar, Electric, Rhythm CountrySwingGrittyA-B Sw 110 OK
# Guitar, Electric, Rhythm CountrySwingGrittyA-B Sw 140 OK
# Guitar, Electric, Rhythm CountryTrainBeatBrent12-key Ev16 090 OK
# Guitar, Electric, Rhythm CountryWaltzCleanA-B Sw 085 OK
# Guitar, Electric, Rhythm CountryWaltzCleanA-B Sw 140 OK
# Guitar, Electric, Rhythm CountryWaltzGrittyA-B Sw 085 OK
# Guitar, Electric, Rhythm CountryWaltzGrittyA-B Sw 110 OK
# Guitar, Electric, Rhythm CountryWaltzGrittyA-B Sw 140 OK
# Guitar, Electric, Rhythm CrossoverChop Sw16 090 OK
# Guitar, Electric, Rhythm CrossoverClean Sw16 090 OK
# Guitar, Electric, Rhythm CrossoverGrooving Sw16 075 OK
# Guitar, Electric, Rhythm Dire Ev 085 OK
# Guitar, Electric, Rhythm Dire Ev 120 OK
# Guitar, Electric, Rhythm Dire Ev 140 OK
# Guitar, Electric, Rhythm Dreamy Ev 085 OK
# Guitar, Electric, Rhythm Dreamy Ev 120 OK
# Guitar, Electric, Rhythm Dreamy Ev 165 OK
# Guitar, Electric, Rhythm Dreamy Ev 190 OK
# Guitar, Electric, Rhythm DrivingCountryBalladClean Ev 065 OK
# Guitar, Electric, Rhythm DrivingCountryBalladDirty Ev 065 OK
# Guitar, Electric, Rhythm ElecRockArp Ev 120 OK
# Guitar, Electric, Rhythm ElecRockDirty Ev 120 OK
# Guitar, Electric, Rhythm Funk16thsMutedWahWah Ev16 100 OK
# Guitar, Electric, Rhythm Funk16thsWahWah Ev16 100 OK
# Guitar, Electric, Rhythm FunkWahWahChords Ev16 100 OK
# Guitar, Electric, Rhythm FunkyGroove60s Ev 100 OK
# Guitar, Electric, Rhythm GospelSoul8thsBrent Ev16 110 OK
# Guitar, Electric, Rhythm GrittyBluesyPopBrent Ev 100 OK
# Guitar, Electric, Rhythm HardRockLACrispA-B Ev 120 OK
# Guitar, Electric, Rhythm HardRockLAFuzzyA-B Ev 120 OK
# Guitar, Electric, Rhythm HardRockThrash Ev 085 OK
# Guitar, Electric, Rhythm HardRockThrashHollow Ev 085 OK
# Guitar, Electric, Rhythm HardRockWaltzMutedA-B Ev 140 OK
# Guitar, Electric, Rhythm HardRockWaltzSustainA-B Ev 140 OK
# Guitar, Electric, Rhythm Jazz Ballad Sw 085 OK
# Guitar, Electric, Rhythm Jazz Sw 140 OK
# Guitar, Electric, Rhythm Jazz Waltz Sw 140 OK
# Guitar, Electric, Rhythm Jazz WesComp Sw 140 OK
# Guitar, Electric, Rhythm JazzBalladCompOlly12-key Sw 085 OK
# Guitar, Electric, Rhythm JazzBalladFreeComp Sw 060 OK
# Guitar, Electric, Rhythm JazzFunkBreezyChords Ev16 075 OK
# Guitar, Electric, Rhythm JazzFunkBreezyMuted Ev16 075 OK
# Guitar, Electric, Rhythm JazzFunkGroovinChords Ev16 110 OK
# Guitar, Electric, Rhythm JazzFunkGroovinMute Ev16 110 OK
# Guitar, Electric, Rhythm JazzFunkMovinChords Ev16 130 OK
# Guitar, Electric, Rhythm JazzFunkMovinMuted Ev16 130 OK
# Guitar, Electric, Rhythm JazzRock8thsJon Ev 120 OK
# Guitar, Electric, Rhythm JazzSwingCompOlly12-key Sw 140 OK
# Guitar, Electric, Rhythm JazzSwingFreeComp Sw 110 OK
# Guitar, Electric, Rhythm JazzSwingFreeComp Sw 190 OK
# Guitar, Electric, Rhythm JazzSwingGrooveComp Sw 110 OK
# Guitar, Electric, Rhythm JazzSwingGrooveComp Sw 190 OK
# Guitar, Electric, Rhythm JazzWaltzCompOlly12-key Sw 110 OK
# Guitar, Electric, Rhythm JazzWaltzFreeComp Sw 085 OK
# Guitar, Electric, Rhythm JazzWaltzFreeComp Sw 110 OK
# Guitar, Electric, Rhythm MemphisCleanA-B Sw 190 OK
# Guitar, Electric, Rhythm MemphisDirtyA-B Sw 190 OK
# Guitar, Electric, Rhythm Metal Ev 085 OK
# Guitar, Electric, Rhythm Metal Ev 120 OK
# Guitar, Electric, Rhythm Metal Ev 165 OK
# Guitar, Electric, Rhythm ModernCountrySync Ev 100 OK
# Guitar, Electric, Rhythm ModernPop16thsHighZane Ev16 090 OK
# Guitar, Electric, Rhythm ModernPop16thsLowZane Ev16 090 OK
# Guitar, Electric, Rhythm ModernPopHardHighMurray Ev16 075 OK
# Guitar, Electric, Rhythm ModernPopHardMurray Ev16 075 OK
# Guitar, Electric, Rhythm ModernPopSlow16thsZane Ev16 075 OK
# Guitar, Electric, Rhythm ModernPopSw16Zane Sw16 075 OK
# Guitar, Electric, Rhythm ModernPopSwing16HighZane Sw16 075 OK
# Guitar, Electric, Rhythm ModernPopSwingZane Sw 085 OK
# Guitar, Electric, Rhythm ModernRnBRockFunkyA-B Ev 065 OK
# Guitar, Electric, Rhythm ModernRnBRockWarmA-B Ev 065 OK
# Guitar, Electric, Rhythm MotownRnBUptempo Ev 165 OK
# Guitar, Electric, Rhythm NashvillePopClean Ev 120 OK
# Guitar, Electric, Rhythm NashvillePopDirty Ev 120 OK
# Guitar, Electric, Rhythm NewOrleansBoogie Ev 165 OK
# Guitar, Electric, Rhythm NewOrleansMardiGras Ev16 085 OK
# Guitar, Electric, Rhythm NewOrleansShuffle Sw 130 OK
# Guitar, Electric, Rhythm NewOrleansSwinginPop Sw 130 OK
# Guitar, Electric, Rhythm NorthernRockFuzzyA-B Sw16 075 OK
# Guitar, Electric, Rhythm NorthernRockGrittyA-B Sw16 075 OK
# Guitar, Electric, Rhythm Pop16thsA-B Ev16 065 OK
# Guitar, Electric, Rhythm Pop16thsA-B Ev16 085 OK
# Guitar, Electric, Rhythm Pop16thsGritty Ev16 110 OK
# Guitar, Electric, Rhythm Pop8thsZaneHigh Ev 120 OK
# Guitar, Electric, Rhythm Pop8thsZaneLow Ev 120 OK
# Guitar, Electric, Rhythm PopAmericanDirty Ev 120 OK
# Guitar, Electric, Rhythm PopAmericanMuted Ev 120 OK
# Guitar, Electric, Rhythm PopBalladClean Ev 085 OK
# Guitar, Electric, Rhythm PopBalladSlowGritty Ev 065 OK
# Guitar, Electric, Rhythm PopBelieveArp Ev16 065 OK
# Guitar, Electric, Rhythm PopBelieveHeld Ev16 065 OK
# Guitar, Electric, Rhythm PopBelieveHeldDry Ev16 065 OK
# Guitar, Electric, Rhythm PopCalypso Ev 100 OK
# Guitar, Electric, Rhythm PopCrossover Sw16 075 OK
# Guitar, Electric, Rhythm PopModernGrooveBrightA-B Ev16 075 OK
# Guitar, Electric, Rhythm PopModernGrooveChorusA-B Ev16 075 OK
# Guitar, Electric, Rhythm PopPowerBrightA-B Ev 120 OK
# Guitar, Electric, Rhythm PopPowerPushA-B Ev 120 OK
# Guitar, Electric, Rhythm PopPromiseCrispA-B Ev16 100 OK
# Guitar, Electric, Rhythm PopPromiseGrittyA-B Ev16 100 OK
# Guitar, Electric, Rhythm PopRockBritEdgy Ev 120 OK
# Guitar, Electric, Rhythm PopRockBritHeavy Ev 120 OK
# Guitar, Electric, Rhythm PopRockWaltzPulsingA-B Ev 140 OK
# Guitar, Electric, Rhythm PopRockWaltzSteadyA-B Ev 140 OK
# Guitar, Electric, Rhythm PopRockWaltzZaneHigh Sw 120 OK
# Guitar, Electric, Rhythm PopRockWaltzZaneLow Sw 120 OK
# Guitar, Electric, Rhythm PopShiningGritty Ev 120 OK
# Guitar, Electric, Rhythm PopShiningGrittyMuted Ev 120 OK
# Guitar, Electric, Rhythm PopShiningRockA-B Ev 120 OK
# Guitar, Electric, Rhythm PopUpliftArp Ev 120 OK
# Guitar, Electric, Rhythm PopUpliftGritty Ev16 120 OK
# Guitar, Electric, Rhythm PopUpliftSyncA-B Ev16 120 OK
# Guitar, Electric, Rhythm PopWaltzClassic Ev 085 OK
# Guitar, Electric, Rhythm PopWaltzGrittyA-B Ev 120 OK
# Guitar, Electric, Rhythm PopWaltzGrittyA-B Ev 180 OK
# Guitar, Electric, Rhythm Punk Ev 165 OK
# Guitar, Electric, Rhythm PunkHeldPlus Ev 165 OK
# Guitar, Electric, Rhythm PunkMuted Ev 165 OK
# Guitar, Electric, Rhythm Reggae Ev16 100 OK
# Guitar, Electric, Rhythm ReggaeSlow Sw 075 OK
# Guitar, Electric, Rhythm RnBSoulSw16Brent Sw16 085 OK
# Guitar, Electric, Rhythm Rock Southern Ev 120 OK
# Guitar, Electric, Rhythm RockBritDriving Ev 085 OK
# Guitar, Electric, Rhythm RockBritSoulful Ev 085 OK
# Guitar, Electric, Rhythm RockHeavy16thsCraig Ev16 090 OK
# Guitar, Electric, Rhythm RockHeavy16thsMurrayA-B Ev16 090 OK
# Guitar, Electric, Rhythm RockHeavy8thsCraig Ev 120 OK
# Guitar, Electric, Rhythm RockHeavy8thsMurray Ev 120 OK
# Guitar, Electric, Rhythm RockHeavyShuffleCraig Sw 120 OK
# Guitar, Electric, Rhythm RockHeavyShuffleMurrayA-B Sw 120 OK
# Guitar, Electric, Rhythm RockabillyBoomChickaBrent Ev 100 OK
# Guitar, Electric, Rhythm RockabillyJiveBrent Sw 190 OK
# Guitar, Electric, Rhythm RockabillyLicksColin Sw 190 OK
# Guitar, Electric, Rhythm RockabillyPickinSwingBrent Sw 190 OK
# Guitar, Electric, Rhythm RockabillyRockNRollBrent Ev 165 OK
# Guitar, Electric, Rhythm RockabillySlowSwingBrent Sw 085 OK
# Guitar, Electric, Rhythm RockabillySwingBrent Sw 165 OK
# Guitar, Electric, Rhythm RootsRockDirty Ev 100 OK
# Guitar, Electric, Rhythm RootsRockTremolo Ev 100 OK
# Guitar, Electric, Rhythm SmoothJazzBallad Ev16 065 OK
# Guitar, Electric, Rhythm SmoothJazzCool Sw16 075 OK
# Guitar, Electric, Rhythm SmoothJazzCool Sw16 100 OK
# Guitar, Electric, Rhythm SmoothJazzPoppy Ev16 090 OK
# Guitar, Electric, Rhythm Soul60sHighA-B Ev 110 OK
# Guitar, Electric, Rhythm Soul60sLowA-B Ev 110 OK
# Guitar, Electric, Rhythm Soul70sBrightA-B Ev16 100 OK
# Guitar, Electric, Rhythm Soul70sWarmA-B Ev16 100 OK
# Guitar, Electric, Rhythm SouthernRock Ev 085 OK
# Guitar, Electric, Rhythm SouthernSnappyClean Ev 090 OK
# Guitar, Electric, Rhythm SouthernSnappyGritty Ev 090 OK
# Guitar, Electric, Rhythm StoneZ Flash 1 Ev 140 OK
# Guitar, Electric, Rhythm StoneZ Flash 2 Ev 140 OK
# Guitar, Electric, Rhythm StoneZ Honky 1 Ev 120 OK
# Guitar, Electric, Rhythm StoneZ Honky 2 Ev 120 OK
# Guitar, Electric, Rhythm SurfRockBrent Ev 165 OK
# Guitar, Electric, Rhythm Swing16WahWah Sw16 085 OK
# Guitar, Electric, Rhythm Syncopated Sugar Ev 102 OK
# Guitar, Electric, Rhythm TexMex2BeatA-B Ev 120 OK
# Guitar, Electric, Rhythm TexMexCountry Ev 120 OK
# Guitar, Electric, Rhythm TexasBluesRockHighA-B Ev 165 OK
# Guitar, Electric, Rhythm TexasBluesRockLowA-B Ev 165 OK
# Guitar, Electric, Rhythm TexasBluesRockShuffleBrent Sw 130 OK
# Guitar, Electric, Rhythm TexasBluesRockShuffleSol Sw 130 OK
# Guitar, Electric, Rhythm TexasBluesRockSlow12-8Brent Sw 060 OK
# Guitar, Electric, Rhythm TexasBluesRockSlow12-8Sol Sw 060 OK
# Guitar, Electric, Rhythm TexasBluesRockStraightBrent Ev 120 OK
# Guitar, Electric, Rhythm TexasBluesRockStraightSol Ev 120 OK
# Guitar, Electric, Rhythm TexasBoogie Sw 140 OK
# Guitar, Electric, Rhythm TexasBoogieShuffle Sw 140 OK
# Guitar, Electric, Rhythm TexasRockChop Ev 120 OK
# Guitar, Electric, Rhythm TexasRockCrisp Ev 120 OK
# Guitar, Electric, Rhythm Train Pickin' Ev 130 OK
# Guitar, Electric, Rhythm Western Swing Sw 165 OK
# Guitar, Electric, Rhythm Western Swing Sw 190 OK
# Guitar, Electric, Rhythm WesternSwingWarmA-B Sw 165 OK
# Guitar, Electric, Rhythm WesternSwingWarmA-B Sw 190 OK
# Guitar, Electric, SoloAccompaniment Bossa Ev 085 OK
# Guitar, Electric, SoloAccompaniment Bossa Ev 140 OK
# Guitar, Electric, SoloAccompaniment Jazz Sw 140 OK
# Guitar, Electric, SoloAccompaniment JazzBallad Sw 060 OK
# Guitar, Electric, SoloAccompaniment JazzBallad Sw 085 OK
# Guitar, Electric, SoloAccompaniment JazzWaltz Sw 085 OK
# Guitar, Electric, SoloAccompaniment JazzWaltz Sw 140 OK
# Guitar, Electric, Soloist Blues BB Ev 085 OK
# Guitar, Electric, Soloist Blues Monday Sw 065 OK
# Guitar, Electric, Soloist Blues Roadhouse Ev 120 OK
# Guitar, Electric, Soloist Blues Sw 120 OK
# Guitar, Electric, Soloist BluesShuffleBrentSimple Sw 130 OK
# Guitar, Electric, Soloist BluesSlow12-8BrentSimple Sw 065 OK
# Guitar, Electric, Soloist BluesSlowEvenBrentSimple Ev 085 OK
# Guitar, Electric, Soloist Bossa Ev 140 OK
# Guitar, Electric, Soloist BossaMike Ev 140 OK
# Guitar, Electric, Soloist BossaPat Ev 140 OK
# Guitar, Electric, Soloist BossaSlow Ev 085 OK
# Guitar, Electric, Soloist Country12-8Brent Sw 065 OK
# Guitar, Electric, Soloist CountryBalladBrentSimple Ev 085 OK
# Guitar, Electric, Soloist CountryBluesRock Ev 110 OK
# Guitar, Electric, Soloist CountryBoogieBrent Sw 140 OK
# Guitar, Electric, Soloist CountryBrent Ev 065 OK
# Guitar, Electric, Soloist CountryBrent Ev 085 OK
# Guitar, Electric, Soloist CountryBrent Ev 120 OK
# Guitar, Electric, Soloist CountryBrent Ev 165 OK
# Guitar, Electric, Soloist CountryClassicSwing Sw 190 OK
# Guitar, Electric, Soloist CountryCrossoverBrent Sw16 075 OK
# Guitar, Electric, Soloist CountryPopBrent12-key Ev 085 OK
# Guitar, Electric, Soloist CountryShuffleBrent Sw 120 OK
# Guitar, Electric, Soloist CountryTrainBrent Ev 140 OK
# Guitar, Electric, Soloist CountryWaltzBrent Sw 085 OK
# Guitar, Electric, Soloist CountryWorkinBrent Ev16 090 OK
# Guitar, Electric, Soloist Cowboy Ev 165 OK
# Guitar, Electric, Soloist Dire Ev 140 OK
# Guitar, Electric, Soloist DrivingCountryBallad Ev 065 OK
# Guitar, Electric, Soloist GypsyClassicQuinn Sw 220 OK
# Guitar, Electric, Soloist Jazz Ballad Sw 085 OK
# Guitar, Electric, Soloist Jazz Sw 140 OK
# Guitar, Electric, Soloist JazzBalladPat Sw 060 OK
# Guitar, Electric, Soloist JazzFastPat Sw 190 OK
# Guitar, Electric, Soloist JazzFunkGroovin Ev16 110 OK
# Guitar, Electric, Soloist JazzRock16thsJon Ev16 090 OK
# Guitar, Electric, Soloist JazzRock8thsJon Ev 120 OK
# Guitar, Electric, Soloist JazzRockShuffleJon Sw 130 OK
# Guitar, Electric, Soloist JazzSwing Sw 060 OK
# Guitar, Electric, Soloist JazzSwing Sw 110 OK
# Guitar, Electric, Soloist JazzSwing Sw 190 OK
# Guitar, Electric, Soloist JazzSwingMike Sw 140 OK
# Guitar, Electric, Soloist JazzWaltz Sw 085 OK
# Guitar, Electric, Soloist JazzWaltz Sw 110 OK
# Guitar, Electric, Soloist Metal Ev 085 OK
# Guitar, Electric, Soloist Metal Ev 120 OK
# Guitar, Electric, Soloist Metal Wild Ev 120 OK
# Guitar, Electric, Soloist PopBelieve Ev16 065 OK
# Guitar, Electric, Soloist PopModernGrooveGritty Ev16 075 OK
# Guitar, Electric, Soloist PopPower Ev 120 OK
# Guitar, Electric, Soloist PopPromiseBrent Ev16 100 OK
# Guitar, Electric, Soloist PopShining Ev 120 OK
# Guitar, Electric, Soloist PopUplift Ev16 120 OK
# Guitar, Electric, Soloist PunkMurray Ev 165 OK
# Guitar, Electric, Soloist RockBalladBrent Ev 065 OK
# Guitar, Electric, Soloist RockBrentSimple Ev 120 OK
# Guitar, Electric, Soloist RockMediumBrent Ev 120 OK
# Guitar, Electric, Soloist RockUpbeatBrent Ev 140 OK
# Guitar, Electric, Soloist RockabillyJiveBrent Sw 190 OK
# Guitar, Electric, Soloist Slow16thsPopBrentSimple Ev16 075 OK
# Guitar, Electric, Soloist SmoothJazzCool Sw16 100 OK
# Guitar, Electric, Soloist SmoothJazzPoppy Ev16 090 OK
# Guitar, Electric, Soloist SmoothSoulFast16thsBrent Ev16 110 OK
# Guitar, Electric, Soloist SmoothSoulSlowBrent Ev 085 OK
# Guitar, Electric, Soloist TexasBluesRockNRollBrent Ev 165 OK
# Guitar, Electric, Soloist TexasBluesRockNRollSol Ev 165 OK
# Guitar, Electric, Soloist TexasBluesRockShuffleBrent Sw 130 OK
# Guitar, Electric, Soloist TexasBluesRockShuffleSol Sw 130 OK
# Guitar, Electric, Soloist TexasBluesRockSlow12-8Brent Sw 060 OK
# Guitar, Electric, Soloist TexasBluesRockSlow12-8Sol Sw 060 OK
# Guitar, Electric, Soloist TexasBluesRockStraightBrent Ev 120 OK
# Guitar, Electric, Soloist TexasBluesRockStraightSol Ev 120 OK
# Guitar, Electric, Soloist Train Pickin' Ev 130 OK
# Guitar, Electric, Soloist TrainBeatBrent12-key Ev16 090 OK
# Guitar, Electric, Soloist WesternSwingBrent Sw 165 OK
# Guitar, Electric, Strumming CleanBarre Ev 085 OK
# Guitar, Electric, Strumming CleanBarre Ev 120 OK
# Guitar, Electric, Strumming CleanBarre Ev 165 OK
# Guitar, Electric, Strumming CleanOpen Ev 085 OK
# Guitar, Electric, Strumming CleanOpen Ev 120 OK
# Guitar, Electric, Strumming CleanOpen Ev 165 OK
# Guitar, Electric, Strumming DirtyBarre Ev 085 OK
# Guitar, Electric, Strumming DirtyBarre Ev 120 OK
# Guitar, Electric, Strumming DirtyBarre Ev 165 OK
# Guitar, Electric, Strumming DirtyOpen Ev 085 OK
# Guitar, Electric, Strumming DirtyOpen Ev 120 OK
# Guitar, Electric, Strumming DirtyOpen Ev 165 OK
# Guitar, High-Strung Acoustic, Fingerpicking Pop16ths Ev16 085 OK
# Guitar, High-Strung Acoustic, Rhythm Folkie16ths Sw16 085 OK
# Guitar, High-Strung Acoustic, Rhythm NorthernRockBallad Ev 065 OK
# Guitar, High-Strung Acoustic, Rhythm Pop16ths Ev16 065 OK
# Guitar, High-Strung Acoustic, Rhythm Pop16ths Ev16 110 OK
# Guitar, High-Strung Acoustic, Rhythm PopCalypso Ev 100 OK
# Guitar, Nylon, Background CountryBrent Ev 085 OK
# Guitar, Nylon, Background CountryBrent Ev 120 OK
# Guitar, Nylon, Background SlowSwingBrent Sw 065 OK
# Guitar, Nylon, Background SwingBrent Sw 110 OK
# Guitar, Nylon, Background WaltzBrent Sw 085 OK
# Guitar, Nylon, Background WaltzBrent Sw 110 OK
# Guitar, Nylon, Chet Fishin' Sw 120 OK
# Guitar, Nylon, Chet Train Ev 130 OK
# Guitar, Nylon, Fingerpicking CountryBrent Ev 085 OK
# Guitar, Nylon, Fingerpicking CountryBrent Ev 120 OK
# Guitar, Nylon, Fingerpicking PeruFestejo68Melodic Sw 120 OK
# Guitar, Nylon, Fingerpicking SlowSwingBrent Sw 065 OK
# Guitar, Nylon, Fingerpicking SwingBrent Sw 110 OK
# Guitar, Nylon, Rhythm AndesHuayno Ev16 085 OK
# Guitar, Nylon, Rhythm BossaGrooveComp Ev 085 OK
# Guitar, Nylon, Rhythm BossaGrooveComp Ev 140 OK
# Guitar, Nylon, Rhythm CountryWaltzBrent Sw 085 OK
# Guitar, Nylon, Rhythm Mariachi68 Sw 110 OK
# Guitar, Nylon, Rhythm MariachiWaltz Ev 150 OK
# Guitar, Nylon, Rhythm PeruFestejo68 Sw 120 OK
# Guitar, Nylon, Rhythm PeruValsCriollo Ev 140 OK
# Guitar, Nylon, Rhythm PuertoRicoAguinaldo Ev16 120 OK
# Guitar, Nylon, Rhythm SpanishTangoQuinn Ev 120 OK
# Guitar, Nylon, Soloist Samba Ev 190 OK
# Guitar, Nylon-Elec, Rhythm Bossa Ev 140 OK
# Guitar, Resonator, Background Allis Ev 120 OK
# Guitar, Resonator, Background BluegrassWaltz Ev 140 OK
# Guitar, Resonator, Background CountryWaltzRandy Sw 110 OK
# Guitar, Resonator, Background Cowboy Ev 165 OK
# Guitar, Resonator, Background Hank Sw 130 OK
# Guitar, Resonator, Background Hayride Sw 190 OK
# Guitar, Resonator, Background Roundup Sw 120 OK
# Guitar, Resonator, Background Trav Ev 088 OK
# Guitar, Resonator, Rhythm Folk8thsRandy Ev 085 OK
# Guitar, Resonator, RhythmPlus Blues8thsRandy Ev 085 OK
# Guitar, Resonator, RhythmPlus BluesFunkyRandy Sw16 075 OK
# Guitar, Resonator, Soloist Country12-8Rob Sw 065 OK
# Guitar, Resonator, Soloist CountryRob Ev 065 OK
# Guitar, Resonator, Soloist CountryRob Ev 085 OK
# Guitar, Resonator, Soloist CountryRob Ev 120 OK
# Guitar, Resonator, Soloist CountryRob Ev 165 OK
# Guitar, Resonator, Soloist CountryShuffleRob Sw 120 OK
# Guitar, Resonator, Soloist CountryTrainRob Ev16 130 OK
# Guitar, Resonator, Soloist CountryWaltzRob Sw 085 OK
# Guitar, Resonator, Soloist CountryWorkinRob Ev16 090 OK
# Guitar, Resonator, Soloist WesternSwingRob Sw 165 OK
# Guitar, Resophonic, Rhythm Blues Crossroads Ev 085 OK
# Guitar, Resophonic, Rhythm Blues Delta Sw 065 OK
# Guitar, Resophonic, Rhythm Blues Muddy Sw 120 OK
# Guitar, Resophonic, Rhythm Blues Roadhouse Ev 120 OK
# Guitar, Slide, Background Blues Ev 085 OK
# Guitar, Slide, Background EasySouthern Ev 120 OK
# Guitar, Slide, Background EasySouthern Ev 165 OK
# Guitar, Slide, Soloist Blues Monday Sw 060 OK
# Guitar, Slide, Soloist Blues Sw 120 OK
# Guitar, Slide, Soloist Blues Sw 165 OK
# Guitarron, Mariachi68 Sw 110 OK
# Guitarron, MariachiWaltz Ev 150 OK
# Harmonica, Background Blues BB Ev 085 OK
# Harmonica, Background Blues Monday Sw 065 OK
# Harmonica, Background Blues Roadhouse Ev 120 OK
# Harmonica, Background Blues Sw 120 OK
# Harmonica, Background CountryBalladJellyRoll Ev 085 OK
# Harmonica, Background CountryPopJellyRoll Ev 120 OK
# Harmonica, Background CountrySlowSwingJellyRoll Sw 085 OK
# Harmonica, Background CountrySwingJellyRoll Sw 120 OK
# Harmonica, Background CountryWaltzFastJellyRoll Ev 140 OK
# Harmonica, Background CountryWaltzSlowJellyRoll Sw 085 OK
# Harmonica, Background Hayride Sw 190 OK
# Harmonica, Background HeeHaw Sw 165 OK
# Harmonica, Background Pop Ev 120 OK
# Harmonica, Background Pop Ev 165 OK
# Harmonica, Background Travis Ev 085 OK
# Harmonica, Soloist Blues Sw 120 OK
# Harmonica, Soloist Train Ev 130 OK
# Harp, Rhythm Celtic16ths Ev16 075 OK
# Harp, Rhythm CelticHornpipe Sw16 070 OK
# Harp, Rhythm CelticJig Sw 110 OK
# Harp, Rhythm CelticWaltz Ev 110 OK
# Harp, Rhythm CelticWaltzSlow Ev 085 OK
# Harp, Rhythm ClassicalSlow8ths Ev 085 OK
# Harp, Rhythm ClassicalSwing Sw 110 OK
# Horn Section, Background CroonerBallad11-Part Sw 060 OK
# Horn Section, Background CroonerBigBand9-Part Sw 110 OK
# Horn Section, Background CroonerBossa10-Part Ev 110 OK
# Horn Section, Background JazzBallad2PartJack Sw 085 OK
# Horn Section, Background JazzSwing2PartJack Sw 140 OK
# Horn Section, Background, R&B Ev16 110 OK
# Horn Section, Rhythm MelodicOldWorld2Beat2Part Ev16 140 OK
# Horn Section, Rhythm MelodicOldWorldWaltz2Part Ev 180 OK
# Horn Section, Rhythm SlowPop Ev16 065 OK
# Horn Section, Rhythm, Funk 2-part, Ev 110 OK
# Horn Section, Soloist CroonerBigBandShoutChorus11-Part Sw 110 OK
# Koto, Synth, Rhythm NewAge Ev 110 OK
# Mandolin Soloist Bluegrass Ev 100 OK
# Mandolin, Rhythm Bluegrass Doc Ev 100 OK
# Mandolin, Rhythm Bluegrass Ev 130 OK
# Mandolin, Rhythm BluegrassWaltz Ev 140 OK
# Mandolin, Rhythm BluegrassWaltz Sw 085 OK
# Mandolin, Rhythm Bouncy Sw 165 OK
# Mandolin, Rhythm Chop Sw 120 OK
# Mandolin, Rhythm Fast Chop Sw 190 OK
# Mandolin, Rhythm ModernCountrySync Ev16 100 OK
# Mandolin, Rhythm Pop16Melodic Ev 065 OK
# Mandolin, Rhythm Pop16Sync Ev 085 OK
# Mandolin, Rhythm Pop16Sync Ev 110 OK
# Mandolin, Rhythm Pop8ths Ev 110 OK
# Mandolin, Rhythm PopModernGrooveAndy Ev16 075 OK
# Mandolin, Rhythm PopUpliftingAndy Ev16 120 OK
# Mandolin, Rhythm PopWaltz Ev 120 OK
# Mandolin, Rhythm PopWaltz Ev 180 OK
# Mandolin, Soloist Bluegrass Ev 130 OK
# Mandolin, Soloist Country12-8Andy Sw 065 OK
# Mandolin, Soloist CountryAndy Ev 065 OK
# Mandolin, Soloist CountryAndy Ev 085 OK
# Mandolin, Soloist CountryAndy Ev 120 OK
# Mandolin, Soloist CountryAndy Ev 165 OK
# Mandolin, Soloist CountryShuffleAndy Sw 120 OK
# Mandolin, Soloist CountryWaltzAndy Sw 085 OK
# Mandolin, Soloist WesternSwingAndy Sw 165 OK
# Organ, B3, Background Blues BB Ev 085 OK
# Organ, B3, Background Blues Monday Sw 065 OK
# Organ, B3, Background Blues Roadhouse Ev 120 OK
# Organ, B3, Background Blues Sw 120 OK
# Organ, B3, Background Pop Ev 065 OK
# Organ, B3, Background Pop Ev 085 OK
# Organ, B3, Background Pop Ev 120 OK
# Organ, B3, Background Pop Ev 165 OK
# Organ, B3, Background Southern Ev 120 OK
# Organ, B3, Rhythm Jazz Sw 110 OK
# Organ, B3, Rhythm Jazz Sw 140 OK
# Organ, B3, Rhythm JazzBallad Sw 060 OK
# Organ, B3, Rhythm JazzBallad Sw 085 OK
# Organ, B3, Rhythm JazzBebop Sw 190 OK
# Organ, B3, Rhythm Reggae Ev16 100 OK
# Organ, B3, Rhythm ReggaeSlow Sw 075 OK
# Organ, Rhythm BluesShuffleMike Sw 130 OK
# Organ, Rhythm BluesSlow128Mike Sw 065 OK
# Organ, Rhythm BluesSlowSwingMike Sw 085 OK
# Organ, Rhythm CountryBluesRockMike Ev 110 OK
# Organ, Rhythm Funk Ev 100 OK
# Organ, Rhythm FunkSwing16 Sw16 085 OK
# ...
# Piano, Acoustic, Rhythm PopWaltz Ev 180 OK
# Piano, Acoustic, Rhythm PraiseBreakA-B Ev 140 OK
# Piano, Acoustic, Rhythm Reggae Ev16 100 OK
# Piano, Acoustic, Rhythm ReggaeSlow Sw 075 OK
# Piano, Acoustic, Rhythm RnBSoulSw16Mike Sw16 085 OK
# Piano, Acoustic, Rhythm RockNRollJohn Ev 165 OK
# Piano, Acoustic, Rhythm RockabillyBoomChickaKevin Ev 100 OK
# Piano, Acoustic, Rhythm RockabillyJiveKevin Sw 190 OK
# Piano, Acoustic, Rhythm RockabillyRockNRollKevin Ev 165 OK
# Piano, Acoustic, Rhythm RockabillyRockNRollKevin Ev 165 (Soft LH) OK
# Piano, Acoustic, Rhythm RockabillySlowSwingKevin Sw 085 OK
# Piano, Acoustic, Rhythm RockabillySwingKevin Sw 165 OK
# Piano, Acoustic, Rhythm Rumba Ev 110 OK
# Piano, Acoustic, Rhythm Samba Ev 190 OK
# Piano, Acoustic, Rhythm SmoothJazzBallad Ev16 065 OK
# Piano, Acoustic, Rhythm SmoothJazzCool Sw16 075 OK
# Piano, Acoustic, Rhythm SmoothJazzCool Sw16 100 OK
# Piano, Acoustic, Rhythm SmoothJazzPoppy Ev16 090 OK
# Piano, Acoustic, Rhythm SmoothSoulFast16thsMike Ev16 110 OK
# Piano, Acoustic, Rhythm SmoothSoulSlowMike Ev 085 OK
# Piano, Acoustic, Rhythm SonMontuno Ev 165 OK
# Piano, Acoustic, Rhythm SonMontunoComp Ev 165 OK
# Piano, Acoustic, Rhythm Soul60sA-B Ev 110 OK
# Piano, Acoustic, Rhythm Soul70sA-B Ev16 100 OK
# Piano, Acoustic, Rhythm SoulJazzMike Ev 130 OK
# Piano, Acoustic, Rhythm SoulfulPop16thsMike Ev16 065 OK
# Piano, Acoustic, Rhythm SouthernRockJohn Sw 120 OK
# Piano, Acoustic, Rhythm Tango Ev 100 OK
# Piano, Acoustic, Rhythm TexasBluesRockJohn Ev 120 OK
# Piano, Acoustic, Rhythm TexasBluesRockShuffle Sw 130 OK
# Piano, Acoustic, Rhythm TrainBeatJohn Ev 130 OK
# Piano, Acoustic, Rhythm TrainBeatMike12-key Ev16 090 OK
# Piano, Acoustic, Solo-Acc PopVancouver Ev 100 OK
# Piano, Acoustic, Solo-Accompaniment Bluesy12-8John Sw 060 OK
# Piano, Acoustic, Solo-Accompaniment CountryPopJohn Ev 085 OK
# Piano, Acoustic, Solo-Accompaniment CountryPopJohn Ev 120 OK
# Piano, Acoustic, Solo-Accompaniment CountrySwingJohn Sw 085 OK
# Piano, Acoustic, Solo-Accompaniment CountrySwingJohn Sw 120 OK
# Piano, Acoustic, Solo-Accompaniment CountryWaltzJohn Sw 085 OK
# Piano, Acoustic, Solo-Accompaniment CountryWaltzJohn Sw 140 OK
# Piano, Acoustic, Solo-Accompaniment FolkPopPrairie Ev 100 OK
# Piano, Acoustic, Solo-Accompaniment Jazz Ballad Sw 085 OK
# Piano, Acoustic, Solo-Accompaniment JazzStride Sw 140 OK
# Piano, Acoustic, Solo-Accompaniment JazzStrideBallad Sw 060 OK
# Piano, Acoustic, Solo-Accompaniment JazzStrideBallad Sw 085 OK
# Piano, Acoustic, Solo-Accompaniment Pop BouncyWaltz Sw 085 OK
# Piano, Acoustic, Solo-Accompaniment PopBalladJohn Ev 110 OK
# Piano, Acoustic, Solo-Accompaniment PopBronx Ev 120 OK
# Piano, Acoustic, Solo-Accompaniment PopFunkyTexas Ev 100 OK
# Piano, Acoustic, Solo-Accompaniment PopLite Ev 140 OK
# Piano, Acoustic, Solo-Accompaniment PopLiverpool Ev 065 OK
# Piano, Acoustic, Solo-Accompaniment PopLondon Ev 065 OK
# Piano, Acoustic, Solo-Accompaniment PopSlow12-8 Ev 060 OK
# Piano, Acoustic, Solo-Accompaniment, PopCalifornia Ev 140 OK
# Piano, Acoustic, Solo-Accompaniment, PopCaliforniaSlow Ev 085 OK
# Piano, Acoustic, Solo-Accompaniment, PopFlowing Ev 120 OK
# Piano, Acoustic, Soloist Country12-8John Sw 065 OK
# Piano, Acoustic, Soloist CountryJohn Ev 065 OK
# Piano, Acoustic, Soloist CountryJohn Ev 120 OK
# Piano, Acoustic, Soloist CountryShuffleJohn Sw 120 OK
# Piano, Acoustic, Soloist CountrySwingJohn Sw 085 OK
# Piano, Acoustic, Soloist CountryWaltzJohn Sw 085 OK
# Piano, Acoustic, Soloist CountryWorkinJohn Ev16 90 OK
# Piano, Acoustic, Soloist Jazz Sw 140 OK
# Piano, Acoustic, Soloist JazzBalladMike Sw 060 OK
# Piano, Acoustic, Soloist JazzMike Sw 110 OK
# Piano, Acoustic, Soloist JazzMike Sw 140 OK
# Piano, Acoustic, Soloist PopRootsyJohn Ev16 100 OK
# Piano, Acoustic, Soloist TexasBluesRockSlow12-8John Sw 060 OK
# Piano, Acoustic, Soloist WesternSwingJohn Sw 165 OK
# Piano, Electric, HeldChords 060 OK
# Piano, Electric, HeldChords 085 OK
# Piano, Electric, Rhythm Bossa Ev 085 OK
# Piano, Electric, Rhythm Bossa Ev 140 OK
# Piano, Electric, Rhythm FunkSwing16 Sw16 085 OK
# Piano, Electric, Rhythm FunkTremolo Ev16 100 OK
# Piano, Electric, Rhythm FusionFastLatinJeff Ev 190 OK
# Piano, Electric, Rhythm FusionSlow16thsJeff Ev16 100 OK
# Piano, Electric, Rhythm Jazz Sw 085 OK
# Piano, Electric, Rhythm Jazz Sw 140 OK
# Piano, Electric, Rhythm JazzBallad Sw 060 OK
# Piano, Electric, Rhythm JazzFunkBreezy Ev16 075 OK
# Piano, Electric, Rhythm JazzFunkGroovin Ev16 110 OK
# Piano, Electric, Rhythm JazzFunkMovin Ev16 130 OK
# Piano, Electric, Rhythm JazzRock Ev16 100 OK
# Piano, Electric, Rhythm JazzWaltz Sw 110 OK
# Piano, Electric, Rhythm JazzySwinginPop Sw 120 OK
# Piano, Electric, Rhythm PepSquad Ev 165 OK
# Piano, Electric, Rhythm SmoothBallad Dry Ev16 065 OK
# Piano, Electric, Rhythm SmoothBallad Ev16 065 OK
# Piano, Electric, Rhythm SmoothCool Dry Sw16 075 OK
# Piano, Electric, Rhythm SmoothCool Dry Sw16 100 OK
# Piano, Electric, Rhythm SmoothCool Sw16 075 OK
# Piano, Electric, Rhythm SmoothCool Sw16 100 OK
# Piano, Electric, Rhythm SmoothPoppy Dry Ev16 090 OK
# Piano, Electric, Rhythm SmoothPoppy Ev16 090 OK
# Piano, Electric, Soloist JazzFunkBreezy Ev16 075 OK
# Piano, Electric, Soloist JazzFunkGroovin Ev16 110 OK
# Piano, Electric, Soloist JazzFunkMovin Ev16 130 OK
# Piano, Electric, Soloist SmoothJazzBallad chorus Ev16 065 OK
# Piano, Electric, Soloist SmoothJazzBallad delay Ev16 065 OK
# Piano, Electric, Soloist SmoothJazzBallad dry Ev16 065 OK
# Piano, Electric, Soloist SmoothJazzCool chorus Sw16 075 OK
# Piano, Electric, Soloist SmoothJazzCool chorus Sw16 100 OK
# Piano, Electric, Soloist SmoothJazzCool delay Sw16 075 OK
# Piano, Electric, Soloist SmoothJazzCool delay Sw16 100 OK
# Piano, Electric, Soloist SmoothJazzCool dry Sw16 075 OK
# Piano, Electric, Soloist SmoothJazzCool dry Sw16 100 OK
# Piano, Electric, Soloist SmoothJazzPoppy chorus Ev16 090 OK
# Piano, Electric, Soloist SmoothJazzPoppy delay Ev16 090 OK
# Piano, Electric, Soloist SmoothJazzPoppy dry Ev16 090 OK
# Piano, ElectricClav, Rhythm FunkyGroovin70sJohn Ev16 100 OK
# Piano, ElectricClav, Rhythm MotownFunkyTripletsJohn Sw 120 OK
# Piano, ElectricVintage, Rhythm BluesyPopMike Ev 100 OK
# Piano, ElectricVintage, Rhythm CoolJazzPop Ev 085 OK
# Piano, ElectricVintage, Rhythm FunkyGroove60sJohn Ev 100 OK
# Piano, ElectricVintage, Rhythm MotownRnBUptempo Ev 165 OK
# Piano, ElectricVintage, Rhythm MotownSlowBluesy12-8John Sw 085 OK
# Piano, ElectricVintage, Rhythm RockabillyMike Sw 190 OK
# Piano, SynthLayer, Rhythm Soul70sA-B Ev16 100 OK
# Sax, Alto, Background CroonerBalladHigh Sw 060 (1TrackHornSection) OK
# Sax, Alto, Background CroonerBalladLow Sw 060 (1TrackHornSection) OK
# Sax, Alto, Background CroonerBigBandHigh Sw 110 (1TrackHornSection) OK
# Sax, Alto, Background CroonerBigBandLow Sw 110 (1TrackHornSection) OK
# Sax, Alto, Background CroonerBossaHigh Ev 110 (1TrackHornSection) OK
# Sax, Alto, Background CroonerBossaLow Ev 110 (1TrackHornSection) OK
# Sax, Alto, Background Funk Ev 110 (1TrackHornSection) OK
# Sax, Alto, Background JazzBalladJack Sw 085 OK
# Sax, Alto, Background JazzSwingJack Sw 140 OK
# Sax, Alto, Bossa Ev 140 OK
# Sax, Alto, Jazz Ballad Sw 085 OK
# Sax, Alto, Jazz Sw 140 OK
# Sax, Alto, Older Sw 140 OK
# Sax, Alto, Rhythm SlowPop Ev16 065 (1TrackHornSection) OK
# Sax, Alto, Soloist BossaPhil Ev 140 OK
# Sax, Alto, Soloist CountryTrainMark Ev16 130 OK
# Sax, Alto, Soloist JazzBalladPhil Sw 085 OK
# Sax, Alto, Soloist JazzFunkGroovin Ev16 110 OK
# Sax, Alto, Soloist JazzPhil Sw 140 OK
# Sax, Alto, Soloist JazzWaltzPhil Sw 140 OK
# Sax, Alto, Soloist SmoothJazzCool Sw16 075 OK
# Sax, Alto, Soloist SmoothJazzCool Sw16 100 OK
# Sax, Alto, Soloist SmoothJazzPoppy Ev16 090 OK
# Sax, Alto, Soloist TexasBluesRockNRollMark Ev 165 OK
# Sax, Alto, Soloist TexasBluesRockShuffleMark Sw 130 OK
# Sax, Alto, Soloist TexasBluesRockSlow12-8Mark Sw 060 OK
# Sax, Alto, Soloist TexasBluesRockStraightMark Ev 120 OK
# Sax, Baritone, Background BluesShuffleGary Sw 130 OK
# Sax, Baritone, Background CroonerBallad Sw 060 (1TrackHornSection) OK
# Sax, Baritone, Background CroonerBigBand Sw 110 (1TrackHornSection) OK
# Sax, Baritone, Background CroonerBossa Ev 110 (1TrackHornSection) OK
# Sax, Baritone, Background RockNRollBluesGary Ev 165 OK
# Sax, Baritone, Background StraightBluesGary Ev 120 OK
# Sax, Baritone, Background, R&B Ev16 110 OK
# Sax, Baritone, Rhythm SlowPop Ev16 065 (1TrackHornSection) OK
# Sax, Baritone, Soloist BluesShuffleGary Sw 130 OK
# Sax, Baritone, Soloist BluesStraightGary Ev 120 OK
# Sax, Baritone, Soloist BossaGary Ev 140 OK
# Sax, Baritone, Soloist JazzBalladGary Sw 085 OK
# Sax, Baritone, Soloist JazzSwingGary Sw 140 OK
# Sax, Baritone, Soloist JazzWaltzGary Sw 140 OK
# Sax, Baritone, Soloist RockNRollBluesGary Ev 165 OK
# Sax, Baritone, Soloist Slow128BluesGary Sw 060 OK
# Sax, Soprano, Soloist BossaJack Ev 140 OK
# Sax, Soprano, Soloist Jazz Swing Sw 110 OK
# Sax, Soprano, Soloist JazzSwing Sw 140 OK
# Sax, Soprano, Soloist JazzWaltzJack Sw 110 OK
# Sax, Soprano, Soloist Samba Ev 190 OK
# Sax, Soprano, Soloist SmoothJazzBallad Ev16 065 OK
# Sax, Soprano, Soloist SmoothJazzCoolJack Sw16 075 OK
# Sax, Tenor, 2-Beat Rock Ev 110 OK
# Sax, Tenor, Background CroonerBalladHigh Sw 060 (1TrackHornSection) OK
# Sax, Tenor, Background CroonerBalladLow Sw 060 (1TrackHornSection) OK
# Sax, Tenor, Background CroonerBigBandHigh Sw 110 (1TrackHornSection) OK
# Sax, Tenor, Background CroonerBigBandLow Sw 110 (1TrackHornSection) OK
# Sax, Tenor, Background CroonerBossaHigh Ev 110 (1TrackHornSection) OK
# Sax, Tenor, Background CroonerBossaLow Ev 110 (1TrackHornSection) OK
# Sax, Tenor, Background Funk Ev 110 (1TrackHornSection) OK
# Sax, Tenor, Background JazzBalladJack Sw 085 OK
# Sax, Tenor, Background JazzSwingJack Sw 140 OK
# Sax, Tenor, Background, R&B Ev16 110 OK
# Sax, Tenor, HipHop Rock Sw 100 OK
# Sax, Tenor, Jazz Sw 140 OK
# Sax, Tenor, Motown Rock Ev 120 OK
# Sax, Tenor, Rhythm SlowPop Ev16 065 (1TrackHornSection) OK
# Sax, Tenor, Soloist BossaEric Ev 140 OK
# Sax, Tenor, Soloist BossaSlowJack Ev 085 OK
# Sax, Tenor, Soloist CountryShuffleMark Sw 120 OK
# Sax, Tenor, Soloist Jazz Ballad Sw 060 OK
# Sax, Tenor, Soloist Jazz BeBop Sw 190 OK
# Sax, Tenor, Soloist Jazz Waltz Sw 140 OK
# Sax, Tenor, Soloist JazzBalladEric Sw 085 OK
# Sax, Tenor, Soloist JazzFunkBreezy Ev16 075 OK
# Sax, Tenor, Soloist JazzFunkMovin Ev16 130 OK
# Sax, Tenor, Soloist JazzSwingEric Sw 140 OK
# Sax, Tenor, Soloist JazzWaltzEric Sw 110 OK
# Sax, Tenor, Soloist PopCountryMark Ev 085 OK
# Sax, Tenor, Soloist Rock Boogie Ev 160 OK
# Sax, Tenor, Soloist SmoothJazzCool Sw16 100 OK
# Shakuhachi, Synth, Background NewAge Ev 110 OK
# String Quartet, Rhythm PopChamber Ev 085 OK
# String Quartet, Rhythm PopEvenChamber Ev 120 OK
# String Quartet, Rhythm PopEvenHall Ev 120 OK
# String Quartet, Rhythm PopHall Ev 085 OK
# String Quartet, Rhythm PopSwingChamber Sw 110 OK
# String Quartet, Rhythm PopSwingHall Sw 110 OK
# Strings, Rhythm CelticAir Ev 085 OK
# Strings, Rhythm CelticWaltz Ev 100 OK
# Strings, Rhythm JazzBalladPads Sw 060 OK
# Strings, Rhythm PopCountry Ev 120 OK
# Strings, Rhythm PopCountry Sw 120 OK
# Strings, Rhythm PopCountryWaltz Sw 140 OK
# Synth Pad, PopBelieve Ev16 065 OK
# Synth Pad, PopModernGrooveA-B Ev16 075 OK
# Synth Pad, PopShiningA-B Ev 120 OK
# Synth Pad, PopUplift Ev 120 OK
# Synth, Background DanceRockTensionPad Ev 120 OK
# Synth, Background JazzFunkLead Ev 110 OK
# Synth, Bass, EuroDance VerseChorusBassA-B Ev16 120 OK
# Synth, BellPad, Rhythm 80sPopMelodic Ev 085 OK
# Synth, BellPad, Rhythm 80sPopMelodic Ev 120 OK
# Synth, BellPad, Rhythm 80sPopPads Ev 085 OK
# Synth, BellPad, Rhythm 80sPopPads Ev 120 OK
# Synth, BellPad, Rhythm 80sPopPads Ev 140 OK
# Synth, ElectroFlutes, Rhythm Pop Ev 085 OK
# Synth, Rhythm AltHipHopHorn Ev16 085 OK
# Synth, Rhythm AltHipHopPadA-B Ev16 085 OK
# Synth, Rhythm BubblegumPopAccentSynth Ev 140 OK
# Synth, Rhythm BubblegumPopKoto Ev 140 OK
# Synth, Rhythm BubblegumPopPluckySynth Ev 140 OK
# Synth, Rhythm BubblegumPopSynthBells Ev 140 OK
# Synth, Rhythm BubblegumPopSynthPads Ev 140 OK
# Synth, Rhythm CloudRapHighOrgan Ev16 075 OK
# Synth, Rhythm CloudRapLowOrgan Ev16 075 OK
# Synth, Rhythm CloudRapPercussive Ev16 075 OK
# Synth, Rhythm DanceRockKoto Ev 120 OK
# Synth, Rhythm DancehallBassGlitch Ev16 085 OK
# Synth, Rhythm DancehallOctaveAB Ev16 085 OK
# Synth, Rhythm DancehallPercussive Ev16 085 OK
# Synth, Rhythm DancehallVocalPad Ev16 085 OK
# Synth, Rhythm DiscoDigiBell Ev 120 OK
# Synth, Rhythm DiscoDigiLead Ev 120 OK
# Synth, Rhythm DiscoElPianoA-B Ev 120 OK
# Synth, Rhythm DiscoShakuhachiA-B Ev 120 OK
# Synth, Rhythm DiscoSynthGuitDelayA-B Ev 120 OK
# Synth, Rhythm JazzFunkPad Ev 110 OK
# Synth, Rhythm JazzFunkPlucky Ev 110 OK
# Synth, Rhythm ModernDancePopRave16thsTickle Ev 120 OK
# Synth, Rhythm ModernDancePopRaveDrops Ev 120 OK
# Synth, Rhythm ModernDancePopRaveMajestic Ev 120 OK
# Synth, Rhythm ModernDancePopRaveOctaveSyncTickle Ev 120 OK
# Synth, Rhythm ModernDancePopRaveStringsHeld Ev 120 OK
# Synth, Rhythm ModernDancePopRaveStringsSync Ev 120 OK
# Synth, Rhythm ModernDancePopSynthGuitar Ev 120 OK
# Synth, Rhythm MutedMelody Ev16 120 OK
# Synth, Rhythm PepSquadHorns Ev 165 OK
# Synth, Rhythm PepSquadPad Ev 165 OK
# Synth, Rhythm PopBell8ths Ev 120 OK
# Synth, Rhythm Rock80s Ev 120 OK
# Synth, Rhythm TropicalHouseLeadA-B Ev 120 OK
# Synth, Rhythm TropicalHousePiano Ev 120 OK
# Synth, Rhythm TropicalHouseSaw Ev 120 OK
# Synth, Rhythm, EuroDance HitsA-B Ev16 120 OK
# Synth, Rhythm, EuroDance HousePianoA-B Ev16 120 OK
# Synth, Rhythm, EuroDance Stab7HitA-B Ev16 120 OK
# Synth, Rhythm, EuroDance Strings Ev 120 OK
# Synth, Rhythm, EuroDance WhinyPan Ev 120 OK
# Tres, Rhythm Guajira Ev 120 OK
# Tres, Rhythm Guaracha Ev 165 OK
# Tres, Rhythm SonMontuno Ev 165 OK
# Trombone, Bossa Ev 140 OK
# Trombone, Jazz Ballad Sw 085 OK
# Trombone, Jazz Sw 140 OK
# Trombone, Older Sw 140 OK
# Trombone, Soloist DixielandFastA-B Sw 165 OK
# Trombone, Soloist DixielandMediumA-B Sw 110 OK
# Trumpet, Background CroonerBallad Sw 060 (1TrackHornSection) OK
# Trumpet, Background CroonerBigBandHigh Sw 110 (1TrackHornSection) OK
# Trumpet, Background CroonerBigBandLow Sw 110 (1TrackHornSection) OK
# Trumpet, Background CroonerBigBandMed Sw 110 (1TrackHornSection) OK
# Trumpet, Background CroonerBossaHigh Ev 110 (1TrackHornSection) OK
# Trumpet, Background CroonerBossaLow Ev 110 (1TrackHornSection) OK
# Trumpet, Background CroonerBossaMed Ev 110 (1TrackHornSection) OK
# Trumpet, Background MelodicOldWorld2Beat Ev16 140 (1TrackHornSection) OK
# Trumpet, Background MelodicOldWorldWaltz Ev 180 (1TrackHornSection) OK
# Trumpet, Background, R&B Ev16 110 OK
# Trumpet, Bossa Ev 140 OK
# Trumpet, Jazz Ballad Sw 085 OK
# Trumpet, Jazz Sw 140 OK
# Trumpet, Muted, Background CroonerBallad Sw 060 (1TrackHornSection) OK
# Trumpet, Muted, Background CroonerBossa Ev 110 (1TrackHornSection) OK
# Trumpet, Older Sw 140 OK
# Trumpet, Rhythm SlowPop Ev16 065 (1TrackHornSection) OK
# Trumpet, Soloist DixielandFastA-B Sw 165 OK
# Trumpet, Soloist DixielandMediumA-B Sw 110 OK
# Trumpet, Soloist SmoothJazzBallad Ev16 065 OK
# Trumpet, Soloist SmoothJazzCool Sw16 075 OK
# Trumpet, Soloist SmoothJazzCool Sw16 100 OK
# Trumpet, Soloist SmoothJazzPoppy Ev16 090 OK
# Tuba, DixielandFast Sw 165 OK
# Tuba, DixielandMedium Sw 110 OK
# Ukulele, Rhythm FolkSwingBallad Sw 085 OK
# Ukulele, Rhythm FolkWaltz Sw 085 OK
# Ukulele, Strumming FolkSwing Sw 110 OK
# Ukulele, Strumming FolkSwing Sw 140 OK
# Vibes, Rhythm Bossa Ev 085 OK
# Vibes, Rhythm Bossa Ev 140 OK
# Vibes, Rhythm Jazz Sw 110 OK
# Vibes, Rhythm Jazz Sw 140 OK
# Vibes, Rhythm JazzBallad Sw 060 OK
# Vibes, Soloist BossaSteve Ev 140 OK
# Vibes, Soloist JazzBalladSteve Sw 060 OK
# Vibes, Soloist JazzSteve Sw 110 OK
# Vibes, Soloist JazzSteve Sw 140 OK
# Vihuela, Rhythm Mariachi68 Sw 110 OK
# Vihuela, Rhythm MariachiWaltz Ev 150 OK
# Viola, Background PopEven Ev 120 (1TrackStringQuartet) OK
# Viola, Background PopSwing Sw 110 (1TrackStringQuartet) OK
# Viola, Background, Pop Ev 085 (1TrackStringSection) OK
# Violin, Background PopEvenHigh Ev 120 (1TrackStringQuartet) OK
# Violin, Background PopEvenLow Ev 120 (1TrackStringQuartet) OK
# Violin, Background PopSwingHigh Sw 110 (1TrackStringQuartet) OK
# Violin, Background PopSwingLow Sw 110 (1TrackStringQuartet) OK
# Violin, Background, PopHigh Ev 085 (1TrackStringSection) OK
# Violin, Background, PopLow Ev 085 (1TrackStringSection) OK
# Vocal Oohs-Aahs, Rhythm Pop3-part Ev 085 OK

# %%
metadata = natsorted(metadata, key=lambda m: tuple(s['path'] for s in m['segments']), alg=ns.PATH)

# %%
with open('metadata.json', 'w') as f:
    json.dump(metadata, f)

# %%
out_path_pairs = [(os.path.join(OUTPUT_DIR, a['path']), os.path.join(OUTPUT_DIR, b['path']))
                  for m in metadata for a, b in [m['segments']]]
np.random.seed(42)
np.random.shuffle(out_path_pairs)

# %%
np.random.seed(42)
train_pairs, test_pairs = train_test_split(out_path_pairs, test_size=0.01)
train_pairs, val_pairs = train_test_split(train_pairs, test_size=500)
np.random.shuffle(train_pairs)

def write_tuples(tuples, path, shuffle_items=False):
    with open(path, 'w') as f:
        for tup in tuples:
            if shuffle_items:
                tup = np.random.choice(tup, size=len(tup), replace=False)
            print(*tup, sep='\t', file=f)

write_tuples(train_pairs, 'pairs_train', shuffle_items=True)
write_tuples(val_pairs, 'pairs_val')
write_tuples(test_pairs, 'pairs_test')

# %%
# !wc -l pairs_*
# Out:
#     912 pairs_test
#   89724 pairs_train
#     500 pairs_val
#   91136 total

# %%
len(dir_paths)  # 1526
# Out:
# 1526
