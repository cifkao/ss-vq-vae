# %% [markdown]
# # Mixing Secrets data download
#
# This notebook was used to download the Mixing Secrets data.
#
# Copyright 2020 InterDigital R&D and Télécom Paris.
# Author: Ondřej Cífka

# %%
import bs4
import concurrent.futures as cf
import io
import json
import os
import re
import sys
import time
import traceback
import urllib.request
import warnings
import zipfile

from tqdm.auto import tqdm

# %%
HTTP_HEADERS = {
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/85.0.4183.102 Safari/537.36'
}

# %%
if os.path.exists('index.html'):
    warnings.warn('index.html already exists, skipping download')
else:
    req = urllib.request.Request('https://www.cambridge-mt.com/ms/mtk/', headers=HTTP_HEADERS)
    with urllib.request.urlopen(req) as response:
        response_str = response.read()
        with open('index.html', 'wb') as f:
            f.write(response_str)

with open('index.html', 'rb') as f:
    soup = bs4.BeautifulSoup(f.read())
# Out:
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: index.html already exists, skipping download

# %%
metadata = []
for genre_e in soup.find_all(class_='c-mtk__genre'):
    for artist_e in genre_e.find_all(class_='c-mtk__artist'):
        for track_e in artist_e.find_all(class_='m-mtk-track'):
            for download_e in track_e.find_all(class_='m-mtk-download'):
                if re.search(r'Full\s+Multitrack', download_e.find(class_='m-mtk-download__type').text):
                    urls = [a['href'] for a in download_e.find(class_='m-mtk-download__links').find_all('a')]
                    urls = [url for url in urls if url.endswith('.zip')]
                    break

            if not urls:
                break

            metadata.append({
                'track_id': re.match(r'^.*/([^/.]+)_Full(_(Pt)?[0-9]+)?.zip$', urls[0]).group(1),
                'track_name': track_e.find(class_='m-mtk-track__name').text,
                'artist': artist_e.find('h4').text,
                'genre': list(artist_e.find(class_='m-container__title-bar').children)[-1].text,
                'category': genre_e.find('h3').text,
                'urls': urls
            })

# %%
metadata
# Out:
# [{'track_id': 'AbletonesBigBand_CorineCorine',
#   'track_name': "'Corine, Corine'",
#   'artist': 'The Abletones Big Band',
#   'genre': 'Big Band Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/AbletonesBigBand_CorineCorine_Full.zip']},
#  {'track_id': 'AbletonesBigBand_SongOfIndia',
#   'track_name': "'Song Of India'",
#   'artist': 'The Abletones Big Band',
#   'genre': 'Big Band Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/AbletonesBigBand_SongOfIndia_Full.zip']},
#  {'track_id': 'AlanEvansTrio_ImComingHome',
#   'track_name': "'I'm Coming Home'",
#   'artist': 'Alan Evans Trio',
#   'genre': 'Live Funk Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/AlanEvansTrio_ImComingHome_Full.zip']},
#  {'track_id': 'AlejoGranados_RumbaChonta',
#   'track_name': "'Rumba Chonta'",
#   'artist': 'Alejo Granados',
#   'genre': 'Afrocolombian Folk Instrumental',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/AlejoGranados_RumbaChonta_Full.zip']},
#  {'track_id': 'AndrewCole_DeadRoses',
#   'track_name': "'Dead Roses'",
#   'artist': 'Andrew Cole',
#   'genre': 'Acoustic Folk-Pop',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/AndrewCole_DeadRoses_Full.zip']},
#  {'track_id': 'GnessinAcademyOrchestra_PianoConcertoK414',
#   'track_name': "W.A. Mozart's\n'Piano Concerto No.12 K414 (Allegro)'",
#   'artist': 'Andrey Yaroshinsky & The Gnessin Academy Chamber Orchestra',
#   'genre': 'Live Orchestral Recording',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/GnessinAcademyOrchestra_PianoConcertoK414_Full.zip']},
#  {'track_id': 'AngelaThomasWade_MilkCowBlues',
#   'track_name': "'Milk Cow Blues'",
#   'artist': 'Angela Thomas Wade',
#   'genre': 'Country',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/AngelaThomasWade_MilkCowBlues_Full.zip']},
#  {'track_id': 'AnnaBlanton_Rachel',
#   'track_name': "'Rachel'",
#   'artist': 'Anna Blanton',
#   'genre': 'Acoustic Country Pop',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK010/AnnaBlanton_Rachel_Full.zip']},
#  {'track_id': 'AnnaBlanton_Waves',
#   'track_name': "'Waves'",
#   'artist': 'Anna Blanton',
#   'genre': 'Acoustic Country Pop',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK010/AnnaBlanton_Waves_Full.zip']},
#  {'track_id': 'Araujo_TheSagaOfHarrisonCrabfeathers',
#   'track_name': "'The Saga Of Harrison Crabfeathers'",
#   'artist': 'Araujo',
#   'genre': 'Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Araujo_TheSagaOfHarrisonCrabfeathers_Full.zip']},
#  {'track_id': 'AsamClassicalSoloists_JesuJoy',
#   'track_name': "J.S.Bach's\n'Jesu bleibet meine Freude'",
#   'artist': 'Asam Classical Soloists',
#   'genre': 'Classical Chamber Concert',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/AsamClassicalSoloists_JesuJoy_Full.zip']},
#  {'track_id': 'AsamClassicalSoloists_NonLoDiroColLabbro',
#   'track_name': "G.F.Handel's\n'Non Lo Diro Col Labbro'",
#   'artist': 'Asam Classical Soloists',
#   'genre': 'Classical Chamber Concert',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/AsamClassicalSoloists_NonLoDiroColLabbro_Full.zip']},
#  {'track_id': 'BalazsDanielBoogieWoogieTrio_OwnWayToBoogie',
#   'track_name': "'Own Way To Boogie'",
#   'artist': 'The Balazs Daniel Boogie Woogie Trio',
#   'genre': 'Traditional Boogie Woogie',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/BalazsDanielBoogieWoogieTrio_OwnWayToBoogie_Full.zip']},
#  {'track_id': 'Barnstar_Believer',
#   'track_name': "'Believer'",
#   'artist': 'Barnstar!',
#   'genre': 'Contemporary Bluegrass',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/Barnstar_Believer_Full.zip']},
#  {'track_id': 'Barnstar_YouDontKnow',
#   'track_name': "'You Don't Know'",
#   'artist': 'Barnstar!',
#   'genre': 'Contemporary Bluegrass',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/Barnstar_YouDontKnow_Full.zip']},
#  {'track_id': 'MR1106_BlueLitMoon',
#   'track_name': "'Dad's Glad'",
#   'artist': 'Blue Lit Moon',
#   'genre': 'Intimate Acoustic Alt Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK001/MR1106_BlueLitMoon_Full.zip']},
#  {'track_id': 'BolzAndKnecht_HungarianDanceNo5',
#   'track_name': "Brahms'\n'Hungarian Dance No. 5'",
#   'artist': 'Bolz & Knecht',
#   'genre': 'Guitar/Sax Acoustic Duo',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/BolzAndKnecht_HungarianDanceNo5_Full.zip']},
#  {'track_id': 'BolzAndKnecht_Summertime',
#   'track_name': "'Summertime'",
#   'artist': 'Bolz & Knecht',
#   'genre': 'Guitar/Sax Acoustic Duo',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/BolzAndKnecht_Summertime_Full.zip']},
#  {'track_id': 'CamillaFrancescaBull_VaLaisseCoulerMesLarmes',
#   'track_name': "'Va! Laisse Couler Mes Larmes'",
#   'artist': 'Camilla Francesca Bull',
#   'genre': 'Classical Opera',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/CamillaFrancescaBull_VaLaisseCoulerMesLarmes_Full.zip']},
#  {'track_id': 'CamillaFrancescaBull_VoiCheSapete',
#   'track_name': "W.A.Mozart's\n'Voi Che Sapete'",
#   'artist': 'Camilla Francesca Bull',
#   'genre': 'Classical Opera',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/CamillaFrancescaBull_VoiCheSapete_Full.zip']},
#  {'track_id': 'Chalga_SzaradASzaj',
#   'track_name': "'Szárad A Száj'",
#   'artist': 'Chalga',
#   'genre': 'World Jazz/Folk',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/Chalga_SzaradASzaj_Full.zip']},
#  {'track_id': 'ColebrookRoad_BrightAngel',
#   'track_name': "'Bright Angel'",
#   'artist': 'Colebrook Road',
#   'genre': 'Bluegrass',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/ColebrookRoad_BrightAngel_Full.zip']},
#  {'track_id': 'DavidYoungs_DustYouAndMe',
#   'track_name': "'Dust, You And Me'",
#   'artist': 'David Youngs',
#   'genre': 'Intricate Solo Acoustic Guitar',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/DavidYoungs_DustYouAndMe_Full.zip']},
#  {'track_id': 'DavidYoungs_LongOverdue',
#   'track_name': "'Long Overdue'",
#   'artist': 'David Youngs',
#   'genre': 'Intricate Solo Acoustic Guitar',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/DavidYoungs_LongOverdue_Full.zip']},
#  {'track_id': 'DavidYoungs_Technomantra',
#   'track_name': "'Technomantra'",
#   'artist': 'David Youngs',
#   'genre': 'Intricate Solo Acoustic Guitar',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/DavidYoungs_Technomantra_Full.zip']},
#  {'track_id': 'DinoOnTheLoose_QueensLight',
#   'track_name': "'Queen's Light'",
#   'artist': 'Dino On The Loose',
#   'genre': 'Jazz Fusion',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/DinoOnTheLoose_QueensLight_Full.zip']},
#  {'track_id': 'DonCamilloChoir_MarshMarigoldsSong',
#   'track_name': "'The Marsh Marigold's Song'",
#   'artist': 'Don Camillo Choir',
#   'genre': 'German Unaccompanied Choir',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/DonCamilloChoir_MarshMarigoldsSong_Full.zip']},
#  {'track_id': 'DonCamilloChoir_TrudeTheBumblebee',
#   'track_name': "'Trude The Bumblebee'",
#   'artist': 'Don Camillo Choir',
#   'genre': 'German Unaccompanied Choir',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/DonCamilloChoir_TrudeTheBumblebee_Full.zip']},
#  {'track_id': 'DonCamilloChoir_WoodwormSong',
#   'track_name': "'The Woodworm Song'",
#   'artist': 'Don Camillo Choir',
#   'genre': 'German Unaccompanied Choir',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/DonCamilloChoir_WoodwormSong_Full.zip']},
#  {'track_id': 'EddieGarrido_Africa',
#   'track_name': "'Africa'",
#   'artist': 'Eddie Garrido',
#   'genre': 'Latin Jazz/Easy Listening',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/EddieGarrido_Africa_Full.zip']},
#  {'track_id': 'EddieGarrido_Scarlett',
#   'track_name': "'Scarlett'",
#   'artist': 'Eddie Garrido',
#   'genre': 'Latin Jazz/Easy Listening',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/EddieGarrido_Scarlett_Full.zip']},
#  {'track_id': 'EndaReilly_AnNascNua',
#   'track_name': "'An Nasc Nua'",
#   'artist': 'Enda Reilly',
#   'genre': 'Irish-Language Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/EndaReilly_AnNascNua_Full.zip']},
#  {'track_id': 'EndaReilly_CurAnLongAgSeol',
#   'track_name': "'Cur An Long Ag Seol'",
#   'artist': 'Enda Reilly',
#   'genre': 'Irish-Language Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/EndaReilly_CurAnLongAgSeol_Full.zip']},
#  {'track_id': 'EthanWiner_CelloConcerto',
#   'track_name': "NEW!\n'Cello Concerto in A Minor'",
#   'artist': 'Ethan Winer',
#   'genre': 'Overdubbed Orchestral Recording',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/EthanWiner_CelloConcerto_Full.zip']},
#  {'track_id': 'FunnyValentines_SleighRide',
#   'track_name': "'Sleigh Ride'",
#   'artist': 'The Funny Valentines',
#   'genre': 'Jazz Quartet Live Recording',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/FunnyValentines_SleighRide_Full.zip']},
#  {'track_id': 'PatrickTalbot_AReasonToLeave',
#   'track_name': "'A Reason To Leave'",
#   'artist': 'Ghostly Beard',
#   'genre': 'Jazz/Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/PatrickTalbot_AReasonToLeave_Full.zip']},
#  {'track_id': 'PatrickTalbot_Blue',
#   'track_name': "'Blue'",
#   'artist': 'Ghostly Beard',
#   'genre': 'Jazz/Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/PatrickTalbot_Blue_Full.zip']},
#  {'track_id': 'PatrickTalbot_Fool',
#   'track_name': "'Fool'",
#   'artist': 'Ghostly Beard',
#   'genre': 'Jazz/Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/PatrickTalbot_Fool_Full.zip']},
#  {'track_id': 'PatrickTalbot_SetMeFree',
#   'track_name': "'Set Me Free'",
#   'artist': 'Ghostly Beard',
#   'genre': 'Jazz/Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/PatrickTalbot_SetMeFree_Full.zip']},
#  {'track_id': 'PatrickTalbot_UpperHand',
#   'track_name': "'Upper Hand'",
#   'artist': 'Ghostly Beard',
#   'genre': 'Jazz/Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/PatrickTalbot_UpperHand_Full.zip']},
#  {'track_id': 'JadeSafirah_Paraisso',
#   'track_name': "'Paraisso'",
#   'artist': 'Jade Safirah',
#   'genre': 'Brazilian Folk',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/JadeSafirah_Paraisso_Full.zip']},
#  {'track_id': 'JamesMay_HoldOnYou',
#   'track_name': "'Hold On You'",
#   'artist': 'James May',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/JamesMay_HoldOnYou_Full.zip']},
#  {'track_id': 'JamesMay_ElizaJane',
#   'track_name': "'Eliza Jane'",
#   'artist': 'James May',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/JamesMay_ElizaJane_Full.zip']},
#  {'track_id': 'JamesMay_IfYouSay',
#   'track_name': "'If You Say'",
#   'artist': 'James May',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/JamesMay_IfYouSay_Full.zip']},
#  {'track_id': 'MR1210_JamesMay',
#   'track_name': "'On The Line'",
#   'artist': 'James May',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/MR1210_JamesMay_Full.zip']},
#  {'track_id': 'JamesMay_AllSoulsMoon',
#   'track_name': "'All Souls Moon'",
#   'artist': 'James May',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/JamesMay_AllSoulsMoon_Full.zip']},
#  {'track_id': 'JamesMay_DontLetGo',
#   'track_name': "'Don't Let Go'",
#   'artist': 'James May',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/JamesMay_DontLetGo_Full.zip']},
#  {'track_id': 'JeffreyHayat_AlexTheAdventurer',
#   'track_name': "'Alex The Adventurer'",
#   'artist': 'Jeffrey Hayat',
#   'genre': 'Adventure Film Orchestral',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK001/JeffreyHayat_AlexTheAdventurer_Full.zip']},
#  {'track_id': 'MR0804_JesperBuhlTrio',
#   'track_name': "'What Is This Thing Called Love'",
#   'artist': 'Jesper Buhl Trio',
#   'genre': 'Acoustic Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR0804_JesperBuhlTrio_Full.zip']},
#  {'track_id': 'JoannaWard_Away',
#   'track_name': "'Away'",
#   'artist': 'Joanna Ward',
#   'genre': 'Modern Classical',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/JoannaWard_Away_Full.zip']},
#  {'track_id': 'KCLBaroque_TelemannLaLyra',
#   'track_name': "Telemann's\n'La Lyra Overture'",
#   'artist': "King's College London Baroque Orchestra",
#   'genre': 'Baroque Orchestral',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/KCLBaroque_TelemannLaLyra_Full.zip']},
#  {'track_id': 'LindyHipBigBand_MakinWhoopee',
#   'track_name': "'Makin' Whoopee'",
#   'artist': 'Lindy Hip Big Band',
#   'genre': 'Big Band Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK010/LindyHipBigBand_MakinWhoopee_Full.zip']},
#  {'track_id': 'LindyHipBigBand_TheOpener',
#   'track_name': "'The Opener'",
#   'artist': 'Lindy Hip Big Band',
#   'genre': 'Big Band Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK010/LindyHipBigBand_TheOpener_Full.zip']},
#  {'track_id': 'TheLonelyWild_Scar',
#   'track_name': "'Scar'",
#   'artist': 'The Lonely Wild',
#   'genre': 'Indie Folk',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/TheLonelyWild_Scar_Full.zip']},
#  {'track_id': 'TheLongWait_BackHomeToBlue',
#   'track_name': "'Back Home To Blue'",
#   'artist': 'The Long Wait',
#   'genre': 'Country Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/TheLongWait_BackHomeToBlue_Full.zip']},
#  {'track_id': 'TheLongWait_DarkHorses',
#   'track_name': "'Dark Horses'",
#   'artist': 'The Long Wait',
#   'genre': 'Country Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/TheLongWait_DarkHorses_Full.zip']},
#  {'track_id': 'TheLongWait_Drag',
#   'track_name': "'Drag'",
#   'artist': 'The Long Wait',
#   'genre': 'Country Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/TheLongWait_Drag_Full.zip']},
#  {'track_id': 'TheLongWait_LookoutMountain',
#   'track_name': "'Lookout Mountain'",
#   'artist': 'The Long Wait',
#   'genre': 'Country Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/TheLongWait_LookoutMountain_Full.zip']},
#  {'track_id': 'TheLongWait_Santa',
#   'track_name': "'Santa'",
#   'artist': 'The Long Wait',
#   'genre': 'Country Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/TheLongWait_Santa_Full.zip']},
#  {'track_id': 'LorenzoPrice_ChangingThings',
#   'track_name': "'Changing Things (Dorian's Song)'",
#   'artist': 'Lorenzo Price',
#   'genre': 'Cool Jazz Fusion',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/LorenzoPrice_ChangingThings_Full.zip']},
#  {'track_id': 'MaurizioPagnuttiSextet_AllTheGinIsGone',
#   'track_name': "'All The Gin Is Gone'",
#   'artist': 'Maurizio Pagnutti Sextet',
#   'genre': 'Acoustic Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/MaurizioPagnuttiSextet_AllTheGinIsGone_Full.zip']},
#  {'track_id': 'MaurizioPagnuttiSextet_Bess',
#   'track_name': "'Bess'",
#   'artist': 'Maurizio Pagnutti Sextet',
#   'genre': 'Acoustic Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/MaurizioPagnuttiSextet_Bess_Full.zip']},
#  {'track_id': 'MikeSkalandunas_SunDrenched',
#   'track_name': "'Sun Drenched'",
#   'artist': 'Mike Skalandunas',
#   'genre': 'Suspense/Thriller Film Orchestral',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/MikeSkalandunas_SunDrenched_Full.zip']},
#  {'track_id': 'Mirroman_Fever',
#   'track_name': "'Fever'",
#   'artist': 'Mirroman',
#   'genre': 'A Capella Duo',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Mirroman_Fever_Full.zip']},
#  {'track_id': 'NickiBluhmAndTheGramblers_GoGoGo',
#   'track_name': "'Go Go Go'",
#   'artist': 'Nicki Bluhm & The Gramblers',
#   'genre': 'Live Country Soul',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/NickiBluhmAndTheGramblers_GoGoGo_Full.zip']},
#  {'track_id': 'NikolaStajicFtVlasisKostas_Nalim',
#   'track_name': "'Nalim'",
#   'artist': 'Nikola Stajic feat. Vlasis Kostas',
#   'genre': 'Balkan/Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/NikolaStajicFtVlasisKostas_Nalim_Full.zip']},
#  {'track_id': 'Ojebokoren_ThatsEntertainment',
#   'track_name': "'That's Entertainment'",
#   'artist': 'Öjebokören',
#   'genre': 'Choral musical',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/Ojebokoren_ThatsEntertainment_Full.zip']},
#  {'track_id': 'PrettySaro_CarolinaInThePines',
#   'track_name': "'Carolina In The Pines'",
#   'artist': 'Pretty Saro',
#   'genre': 'Bluegrass',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/PrettySaro_CarolinaInThePines_Full.zip']},
#  {'track_id': 'Primakova_TheGlass',
#   'track_name': "'The Glass'",
#   'artist': 'Primakova',
#   'genre': 'Folk Rock',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/Primakova_TheGlass_Full.zip']},
#  {'track_id': 'RodAlexander_Canon',
#   'track_name': "Pachebel's\n'Canon'",
#   'artist': 'Rod Alexander',
#   'genre': 'Guitar Instrumental',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/RodAlexander_Canon_Full.zip']},
#  {'track_id': 'RodAlexander_TearsInTheRain',
#   'track_name': "'Tears In The Rain'",
#   'artist': 'Rod Alexander',
#   'genre': 'Guitar Instrumental',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/RodAlexander_TearsInTheRain_Full.zip']},
#  {'track_id': 'RoversAhead_ItsInTheseTimes',
#   'track_name': "'It's In These Times'",
#   'artist': 'Rovers Ahead',
#   'genre': 'Celtic Folk Punk',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/RoversAhead_ItsInTheseTimes_Full.zip']},
#  {'track_id': 'MR1207_SantiVega',
#   'track_name': "'Ying Yang'",
#   'artist': 'Santi Vega',
#   'genre': 'Intricate Solo Acoustic Guitar',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/MR1207_SantiVega_Full.zip']},
#  {'track_id': 'SelwynJazz_MuchTooMuch',
#   'track_name': "Bill Ashton's\n'Much Too Much'",
#   'artist': 'Selwyn Jazz',
#   'genre': 'Big-Band Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/SelwynJazz_MuchTooMuch_Full.zip']},
#  {'track_id': 'SimonLyn_Copper',
#   'track_name': "'Copper'",
#   'artist': 'Simon Lyn',
#   'genre': 'Atmospheric String Textures',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/SimonLyn_Copper_Full.zip']},
#  {'track_id': 'Spektakulatius_ChristmasBlues',
#   'track_name': "'Christmas Blues'",
#   'artist': 'Spektakulatius',
#   'genre': 'Various Styles',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Spektakulatius_ChristmasBlues_Full.zip']},
#  {'track_id': 'Spektakulatius_JedenWinter',
#   'track_name': "'Jeden Winter'",
#   'artist': 'Spektakulatius',
#   'genre': 'Various Styles',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Spektakulatius_JedenWinter_Full.zip']},
#  {'track_id': 'Spektakulatius_WhatChildIsThis',
#   'track_name': "'What Child Is This'",
#   'artist': 'Spektakulatius',
#   'genre': 'Various Styles',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Spektakulatius_WhatChildIsThis_Full.zip']},
#  {'track_id': 'Spektakulatius_IsYouIsOrIsYouAint',
#   'track_name': "'Is You Is Or Is You Ain't'",
#   'artist': 'Spektakulatius',
#   'genre': 'Various Styles',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Spektakulatius_IsYouIsOrIsYouAint_Full.zip']},
#  {'track_id': 'Spektakulatius_OurLoveIsHereToStay',
#   'track_name': "'Our Love Is Here To Stay'",
#   'artist': 'Spektakulatius',
#   'genre': 'Various Styles',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Spektakulatius_OurLoveIsHereToStay_Full.zip']},
#  {'track_id': 'Spektakulatius_WayfaringStranger',
#   'track_name': "'Wayfaring Stranger'",
#   'artist': 'Spektakulatius',
#   'genre': 'Various Styles',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Spektakulatius_WayfaringStranger_Full.zip']},
#  {'track_id': 'SwingBazar_FlecheDOr',
#   'track_name': "'Fleche D'Or'",
#   'artist': 'Swing Bazar',
#   'genre': 'Gypsy Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/SwingBazar_FlecheDOr_Full.zip']},
#  {'track_id': 'MR0904_TimoCarlier',
#   'track_name': "'The Road Ahead'",
#   'artist': 'Timo Carlier',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR0904_TimoCarlier_Full.zip']},
#  {'track_id': 'MR1304_TomMcKenzie',
#   'track_name': "'Directions'",
#   'artist': 'Tom McKenzie',
#   'genre': 'Acoustic Singer-Songwriter',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/MR1304_TomMcKenzie_Full.zip']},
#  {'track_id': 'UncleDad_WhoIAm',
#   'track_name': "'Who I Am'",
#   'artist': 'Uncle Dad',
#   'genre': 'Acoustic Country',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/UncleDad_WhoIAm_Full.zip']},
#  {'track_id': 'UTGandhi_Arto',
#   'track_name': "'Arto'",
#   'artist': 'U T Gandhi',
#   'genre': 'World Jazz',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/UTGandhi_Arto_Full.zip']},
#  {'track_id': 'MR1108_WolfsHeadAndVixen',
#   'track_name': "'Lament'",
#   'artist': "Wolf's Head & Vixen Morris Band",
#   'genre': 'Acoustic Folk',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK001/MR1108_WolfsHeadAndVixen_Full.zip']},
#  {'track_id': 'WovenHollow_TellMeNice',
#   'track_name': "'Tell Me Nice'",
#   'artist': 'Woven Hollow',
#   'genre': 'Acoustic Singer-Songwriter Duo',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://multitracks.cambridge-mt.com/WovenHollow_TellMeNice_Full.zip']},
#  {'track_id': 'Zwiepack_Air',
#   'track_name': "'Air'",
#   'artist': 'Zwiepack',
#   'genre': 'Jazz Duo/Trio',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK011/Zwiepack_Air_Full.zip']},
#  {'track_id': 'Zwiepack_Summertime',
#   'track_name': "'Summertime'",
#   'artist': 'Zwiepack',
#   'genre': 'Jazz Duo/Trio',
#   'category': 'Acoustic / Jazz / Country / Orchestral',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK011/Zwiepack_Summertime_Full.zip']},
#  {'track_id': 'AlbertKader_Ubiquitous',
#   'track_name': "'Ubiquitous'",
#   'artist': 'Albert Kader',
#   'genre': 'Minimal Techno',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/AlbertKader_Ubiquitous_Full.zip']},
#  {'track_id': 'AlbertKader_Whiptails',
#   'track_name': "'Whiptails'",
#   'artist': 'Albert Kader',
#   'genre': 'Minimal Techno',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/AlbertKader_Whiptails_Full.zip']},
#  {'track_id': 'AMContra_HeartPeripheral',
#   'track_name': "'Heart Peripheral'",
#   'artist': 'AM Contra',
#   'genre': 'Electronic Dance Pop',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/AMContra_HeartPeripheral_Full.zip']},
#  {'track_id': 'APZX_Amalgamize',
#   'track_name': "'Amalgamize'",
#   'artist': 'APZX',
#   'genre': 'Progressive Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/APZX_Amalgamize_Full.zip']},
#  {'track_id': 'APZX_CyberMower',
#   'track_name': "'Cyber Mower'",
#   'artist': 'APZX',
#   'genre': 'Progressive Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/APZX_CyberMower_Full.zip']},
#  {'track_id': 'APZX_FromEarthToPlanetOmega',
#   'track_name': "'From Earth To Planet Omega'",
#   'artist': 'APZX',
#   'genre': 'Progressive Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/APZX_FromEarthToPlanetOmega_Full.zip']},
#  {'track_id': 'APZX_Lacuna',
#   'track_name': "'Lacuna'",
#   'artist': 'APZX',
#   'genre': 'Progressive Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/APZX_Lacuna_Full.zip']},
#  {'track_id': 'APZX_Transcention',
#   'track_name': "'Transcention'",
#   'artist': 'APZX',
#   'genre': 'Progressive Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/APZX_Transcention_Full.zip']},
#  {'track_id': 'AronJaeger_FlyHigh',
#   'track_name': "'Fly High'",
#   'artist': 'Aron Jaeger',
#   'genre': 'Dubstep',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/AronJaeger_FlyHigh_Full.zip']},
#  {'track_id': 'BabeGrand_AiguilleRouge',
#   'track_name': "'Aiguille Rouge'",
#   'artist': 'Babe Grand',
#   'genre': 'Techno',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/BabeGrand_AiguilleRouge_Full.zip']},
#  {'track_id': 'BabeGrand_KingOfTheWeekend',
#   'track_name': "NEW!\n'King Of The Weekend'",
#   'artist': 'Babe Grand',
#   'genre': 'Techno',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/BabeGrand_KingOfTheWeekend_Full.zip']},
#  {'track_id': 'Bravestar_Downtempo',
#   'track_name': "'Downtempo'",
#   'artist': 'Bravestar',
#   'genre': 'Atmospheric Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Bravestar_Downtempo_Full.zip']},
#  {'track_id': 'cfx_Mathematician',
#   'track_name': "'Mathematician'",
#   'artist': 'c:fx',
#   'genre': 'Progressive Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/cfx_Mathematician_Full.zip']},
#  {'track_id': 'CarolDant_DoNotStand',
#   'track_name': "'Do Not Stand'",
#   'artist': 'Carol Dant',
#   'genre': 'Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/CarolDant_DoNotStand_Full.zip']},
#  {'track_id': 'CarolDant_IAmTheDesert',
#   'track_name': "'I Am The Desert'",
#   'artist': 'Carol Dant',
#   'genre': 'Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/CarolDant_IAmTheDesert_Full.zip']},
#  {'track_id': 'MR0905_ChrisDurban',
#   'track_name': "'Celebrate'",
#   'artist': 'Chris Durban',
#   'genre': 'Dark Break-based Dance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK001/MR0905_ChrisDurban_Full.zip']},
#  {'track_id': 'cryonicPAX_AnotherWay',
#   'track_name': "'Another Way'",
#   'artist': 'cryonicPAX',
#   'genre': 'Dubstep/Drum&Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/cryonicPAX_AnotherWay_Full.zip']},
#  {'track_id': 'cryonicPAX_Excessive',
#   'track_name': "'Excessive'",
#   'artist': 'cryonicPAX',
#   'genre': 'Dubstep/Drum&Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/cryonicPAX_Excessive_Full.zip']},
#  {'track_id': 'cryonicPAX_HoldMe',
#   'track_name': "'Hold Me'",
#   'artist': 'cryonicPAX',
#   'genre': 'Dubstep/Drum&Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/cryonicPAX_HoldMe_Full.zip']},
#  {'track_id': 'cryonicPAX_Melancholy',
#   'track_name': "'Melancholy'",
#   'artist': 'cryonicPAX',
#   'genre': 'Dubstep/Drum&Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/cryonicPAX_Melancholy_Full.zip']},
#  {'track_id': 'Fin_Echoes',
#   'track_name': "'Echoes'",
#   'artist': 'FIN',
#   'genre': 'Experimental Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/Fin_Echoes_Full.zip']},
#  {'track_id': 'FranciscoPerez_Spaces',
#   'track_name': "'Spaces'",
#   'artist': 'Francisco Perez',
#   'genre': 'Atmospheric EDM',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/FranciscoPerez_Spaces_Full.zip']},
#  {'track_id': 'Galias_Horizon',
#   'track_name': "'Horizon'",
#   'artist': 'Galias',
#   'genre': 'Tropical House',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/Galias_Horizon_Full.zip']},
#  {'track_id': 'GeorgiaWonder_Siren',
#   'track_name': "'Siren'",
#   'artist': 'Georgia Wonder',
#   'genre': 'Pop Disco/Rock',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/GeorgiaWonder_Siren_Full.zip']},
#  {'track_id': 'MR1011_GirlsUnderGlass',
#   'track_name': "'We Feel Alright'",
#   'artist': 'Girls Under Glass',
#   'genre': 'Gothic Electro',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK001/MR1011_GirlsUnderGlass_Full.zip']},
#  {'track_id': 'IanDearden_TeraniaCreekWalking',
#   'track_name': "'Terania Creek Walking'",
#   'artist': 'Ian Dearden',
#   'genre': 'Ambient Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/IanDearden_TeraniaCreekWalking_Full.zip']},
#  {'track_id': 'IanDearden_ThursdayReverie',
#   'track_name': "'Thursday Reverie'",
#   'artist': 'Ian Dearden',
#   'genre': 'Ambient Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/IanDearden_ThursdayReverie_Full.zip']},
#  {'track_id': 'J0K3R_SeptemberTrance',
#   'track_name': "'September Trance'",
#   'artist': 'J0K3R',
#   'genre': 'Trance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/J0K3R_SeptemberTrance_Full.zip']},
#  {'track_id': 'JamesFabio_MachinesOnTreadmills',
#   'track_name': "'Machines On Treadmills'",
#   'artist': 'James Fabio',
#   'genre': 'Atmospheric Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/JamesFabio_MachinesOnTreadmills_Full.zip']},
#  {'track_id': 'JohnAArdelli_Asiza',
#   'track_name': "'Asiza'",
#   'artist': 'John A Ardelli',
#   'genre': 'Dramatic Short Story',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/JohnAArdelli_Asiza_Full.zip']},
#  {'track_id': 'JPLantieri_Chardonnay',
#   'track_name': "'Chardonnay'",
#   'artist': 'J P Lantieri',
#   'genre': 'Progressive House',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JPLantieri_Chardonnay_Full.zip']},
#  {'track_id': 'JPLantieri_ChardonnayLektrixRemix',
#   'track_name': "'Chardonnay (Lektrix Remix)'",
#   'artist': 'J P Lantieri',
#   'genre': 'Progressive House',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JPLantieri_ChardonnayLektrixRemix_Full.zip']},
#  {'track_id': 'JPLantieri_ChardonnayMystikVibeRemix',
#   'track_name': "'Chardonnay (Mystik Vibe Remix)'",
#   'artist': 'J P Lantieri',
#   'genre': 'Progressive House',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JPLantieri_ChardonnayMystikVibeRemix_Full.zip']},
#  {'track_id': 'JPLantieri_ChardonnayOrneryRemix',
#   'track_name': "'Chardonnay (Ornery Remix)'",
#   'artist': 'J P Lantieri',
#   'genre': 'Progressive House',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JPLantieri_ChardonnayOrneryRemix_Full.zip']},
#  {'track_id': 'JPLantieri_Riesling',
#   'track_name': "'Riesling'",
#   'artist': 'J P Lantieri',
#   'genre': 'Progressive House',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JPLantieri_Riesling_Full_1.zip',
#    'https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JPLantieri_Riesling_Full_2.zip']},
#  {'track_id': 'JulietsRescue_Heartbeats',
#   'track_name': "'Heartbeats'",
#   'artist': "Juliet's Rescue",
#   'genre': 'Club Rock',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/JulietsRescue_Heartbeats_Full.zip']},
#  {'track_id': 'KarlHungus_GotYourLove',
#   'track_name': "'Got Your Love'",
#   'artist': 'Karl Hungus',
#   'genre': 'Trap & Future Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/KarlHungus_GotYourLove_Full.zip']},
#  {'track_id': 'Ludo_Sandstorm',
#   'track_name': "'Sandstorm'",
#   'artist': 'Ludø',
#   'genre': 'Cinematic Soundtrack',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/Ludo_Sandstorm_Full.zip']},
#  {'track_id': 'MountaineeringClubOrchestra_CruisingTheIce',
#   'track_name': "'Cruising The Ice'",
#   'artist': 'The Mountaineering Club Orchestra',
#   'genre': 'Ambient Indie Instrumental',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK004/MountaineeringClubOrchestra_CruisingTheIce_Full.zip']},
#  {'track_id': 'Mu_TooBright',
#   'track_name': "'Too Bright'",
#   'artist': 'μ',
#   'genre': 'Alternative Electro Rock',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Mu_TooBright_Full.zip']},
#  {'track_id': 'MustafaAlbazy_ShelaYaMarhaba',
#   'track_name': "'Shela Ya Marhaba'",
#   'artist': 'Mustafa Albazy',
#   'genre': 'Electronic Dance-Pop',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/MustafaAlbazy_ShelaYaMarhaba_Full.zip']},
#  {'track_id': 'MustafaAlbazy_Tgheer',
#   'track_name': "'Tgheer'",
#   'artist': 'Mustafa Albazy',
#   'genre': 'Electronic Dance-Pop',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/MustafaAlbazy_Tgheer_Full.zip']},
#  {'track_id': 'NahumStrickland_SteampunkSiege',
#   'track_name': "'Steampunk Siege'",
#   'artist': 'Nahum Strickland',
#   'genre': 'Cinematic Soundtrack',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK010/NahumStrickland_SteampunkSiege_Full.zip']},
#  {'track_id': 'Nervbloc_Slapback',
#   'track_name': "'Slapback'",
#   'artist': 'Nervbloc',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/Nervbloc_Slapback_Full.zip']},
#  {'track_id': 'Nominal6_EscapeOfTheHoppingRhinos',
#   'track_name': "'Escape Of The Hopping Rhinos'",
#   'artist': 'Nominal6',
#   'genre': 'Leftfield Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/Nominal6_EscapeOfTheHoppingRhinos_Full.zip']},
#  {'track_id': 'OctopusOnFire_RussianBot',
#   'track_name': "'Russian Bot'",
#   'artist': 'OctopusOnFire',
#   'genre': 'Vocaloid Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/OctopusOnFire_RussianBot_Full.zip']},
#  {'track_id': 'MR0907_Punkdisco',
#   'track_name': "'Oral Hygiene'",
#   'artist': 'Punkdisco',
#   'genre': 'Punk Electronica',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR0907_Punkdisco_Full.zip']},
#  {'track_id': 'Rattletree_JustLetItGo',
#   'track_name': "'Just Let It Go'",
#   'artist': 'Rattletree',
#   'genre': 'Progressive Techtrance',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://multitracks.cambridge-mt.com/Rattletree_JustLetItGo_Full.zip']},
#  {'track_id': 'Skelpolu_AnomalousWeeping',
#   'track_name': "'Anomalous Weeping'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_AnomalousWeeping_Full.zip']},
#  {'track_id': 'Skelpolu_ColdStrive',
#   'track_name': "'Cold Strive'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_ColdStrive_Full.zip']},
#  {'track_id': 'Skelpolu_Entwine',
#   'track_name': "'Entwine'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_Entwine_Full.zip']},
#  {'track_id': 'Skelpolu_HumanMistakes',
#   'track_name': "'Human Mistakes'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_HumanMistakes_Full.zip']},
#  {'track_id': 'Skelpolu_LongRoad',
#   'track_name': "'Long Road'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_LongRoad_Full.zip']},
#  {'track_id': 'Skelpolu_Resurrection',
#   'track_name': "'Resurrection Resurrected'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_Resurrection_Full.zip']},
#  {'track_id': 'Skelpolu_TogetherAlone',
#   'track_name': "'Together Alone'",
#   'artist': 'Skelpolu',
#   'genre': 'Drum & Bass',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Skelpolu_TogetherAlone_Full.zip']},
#  {'track_id': 'SpeakSoftly_BrokenMan',
#   'track_name': "'Broken Man'",
#   'artist': 'Speak Softly',
#   'genre': 'Atmospheric Electronic Pop',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/SpeakSoftly_BrokenMan_Full.zip']},
#  {'track_id': 'SpeakSoftly_LikeHorses',
#   'track_name': "'Like Horses'",
#   'artist': 'Speak Softly',
#   'genre': 'Atmospheric Electronic Pop',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/SpeakSoftly_LikeHorses_Full.zip']},
#  {'track_id': 'SpeakSoftly_NorthIsFalse',
#   'track_name': "'North Is False'",
#   'artist': 'Speak Softly',
#   'genre': 'Atmospheric Electronic Pop',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/SpeakSoftly_NorthIsFalse_Full.zip']},
#  {'track_id': 'TimTaler_Stalker',
#   'track_name': "'Stalker'",
#   'artist': 'Tim Taler',
#   'genre': 'Ukrainian Art-Punk',
#   'category': 'Electronica / Dance / Experimental',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/TimTaler_Stalker_Full.zip']},
#  {'track_id': 'Actions_DevilsWords',
#   'track_name': "'Devil's Words'",
#   'artist': 'Actions',
#   'genre': 'Power Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/Actions_DevilsWords_Full.zip']},
#  {'track_id': 'Actions_OneMinuteSmile',
#   'track_name': "'One Minute Smile'",
#   'artist': 'Actions',
#   'genre': 'Power Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/Actions_OneMinuteSmile_Full.zip']},
#  {'track_id': 'Actions_SouthOfTheWater',
#   'track_name': "'South Of The Water'",
#   'artist': 'Actions',
#   'genre': 'Power Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/Actions_SouthOfTheWater_Full.zip']},
#  {'track_id': 'AdamBuckley_DragMeDown',
#   'track_name': "'Drag me Down'",
#   'artist': 'Adam Buckley',
#   'genre': 'Pop Punk',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/AdamBuckley_DragMeDown_Full.zip']},
#  {'track_id': 'AjayNagarkotiAndVibhuDixit_AeMereHumsafar',
#   'track_name': "'Ae Mere Humsafar'",
#   'artist': 'Ajay Nagarkoti & Vibhu Dixit',
#   'genre': 'Bollywood Hindi Song',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/AjayNagarkotiAndVibhuDixit_AeMereHumsafar_Full.zip']},
#  {'track_id': 'MR0908_AlJames',
#   'track_name': "'Schoolboy Fascination'",
#   'artist': 'Al James',
#   'genre': 'Bubblegum Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/MR0908_AlJames_Full.zip']},
#  {'track_id': 'AmyHelmAndTheHandsomeStrangers_RescueMe',
#   'track_name': "'Rescue Me'",
#   'artist': 'Amy Helm & The Handsome Strangers',
#   'genre': 'Roots Singer-Songwriter',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/AmyHelmAndTheHandsomeStrangers_RescueMe_Full.zip']},
#  {'track_id': 'AngeloBoltini_ThisTown',
#   'track_name': "'This Town'",
#   'artist': 'Angelo Boltini',
#   'genre': 'Orchestral Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://multitracks.cambridge-mt.com/AngeloBoltini_ThisTown_Full.zip']},
#  {'track_id': 'AtlantisBound_ItWasMyFaultForWaiting',
#   'track_name': "'It Was My Fault For Waiting'",
#   'artist': 'Atlantis Bound',
#   'genre': 'Widescreen Pop/Rock',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/AtlantisBound_ItWasMyFaultForWaiting_Full.zip']},
#  {'track_id': 'BaumXmedia_Koishii',
#   'track_name': "NEW!\n'Koishii (feat. N.I.A.)'",
#   'artist': 'BaumXmedia',
#   'genre': 'Pop/R&B',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://multitracks.cambridge-mt.com/BaumXmedia_Koishii_Full.zip']},
#  {'track_id': 'BenCarrigan_HeyCarrieAnne',
#   'track_name': "'Hey Carrie Anne'",
#   'artist': 'Ben Carrigan',
#   'genre': 'Orchestral Indie Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/BenCarrigan_HeyCarrieAnne_Full.zip']},
#  {'track_id': 'BenCarrigan_WellTalkAboutItAllTonight',
#   'track_name': "'We'll Talk About It All Tonight'",
#   'artist': 'Ben Carrigan',
#   'genre': 'Orchestral Indie Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/BenCarrigan_WellTalkAboutItAllTonight_Full.zip']},
#  {'track_id': 'BenjaminJohn_BetterWay',
#   'track_name': "'Better Way'",
#   'artist': 'Benjamin John',
#   'genre': 'Acoustic Indie Pop',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://multitracks.cambridge-mt.com/BenjaminJohn_BetterWay_Full.zip']},
#  {'track_id': 'Bruks_KakTvoiDelaVova',
#   'track_name': "'Kak Tvoi Dela, Vova?'",
#   'artist': 'Bruks',
#   'genre': 'Russian Pop/Rock',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK010/Bruks_KakTvoiDelaVova_Full.zip']},
#  {'track_id': 'CarlosGonzalez_APlaceForUs',
#   'track_name': "'A Place For Us'",
#   'artist': 'Carlitos Gonzalez',
#   'genre': 'Indie Pop/Rock',
#   'category': 'Pop / Singer-Songwriter',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/CarlosGonzalez_APlaceForUs_Full.zip']},
# ...
#   'genre': 'Slightly Surfy Punk',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/TheMaybeNextYears_OneFlipFlop_Full.zip']},
#  {'track_id': 'Mistrusted_CarnivalCharade',
#   'track_name': "NEW!\n'Carnival Charade'",
#   'artist': 'Mistrusted',
#   'genre': 'Grunge/Punk',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/Mistrusted_CarnivalCharade_Full.zip']},
#  {'track_id': 'Mistrusted_Polemic',
#   'track_name': "'Polemic'",
#   'artist': 'Mistrusted',
#   'genre': 'Grunge/Punk',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/Mistrusted_Polemic_Full.zip']},
#  {'track_id': 'MR0912_NorthToAlaska',
#   'track_name': "'All The Same'",
#   'artist': 'North To Alaska',
#   'genre': 'Emo Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/MR0912_NorthToAlaska_Full.zip']},
#  {'track_id': 'NovaOneStudio_FourGraham',
#   'track_name': "'Four Graham'",
#   'artist': 'Nova-One Studio',
#   'genre': 'Pop-Punk',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/NovaOneStudio_FourGraham_Full.zip']},
#  {'track_id': 'PabloMartin_Progresivo1ElVuelo',
#   'track_name': "'Progresivo 1, El Vuelo'",
#   'artist': 'Pablo Martin',
#   'genre': 'Instrumental Progressive Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/PabloMartin_Progresivo1ElVuelo_Full.zip']},
#  {'track_id': 'PaintedSkies_Piers',
#   'track_name': "'Piers'",
#   'artist': 'Painted Skies',
#   'genre': 'Melodic Prog Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/PaintedSkies_Piers_Full.zip']},
#  {'track_id': 'PerpetualEscape_DutyAndMemories',
#   'track_name': "'Duty & Memories'",
#   'artist': 'Perpetual Escape',
#   'genre': 'Progressive Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/PerpetualEscape_DutyAndMemories_Full.zip']},
#  {'track_id': 'PerpetualEscape_IntoMyDreams',
#   'track_name': "'Into My Dreams'",
#   'artist': 'Perpetual Escape',
#   'genre': 'Progressive Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/PerpetualEscape_IntoMyDreams_Full_1.zip',
#    'https://multitracks.cambridge-mt.com/PerpetualEscape_IntoMyDreams_Full_2.zip',
#    'https://multitracks.cambridge-mt.com/PerpetualEscape_IntoMyDreams_Full_3.zip',
#    'https://multitracks.cambridge-mt.com/PerpetualEscape_IntoMyDreams_Full_4.zip']},
#  {'track_id': 'PerpetualEscape_RootsOfMankind',
#   'track_name': "'Roots Of Mankind'",
#   'artist': 'Perpetual Escape',
#   'genre': 'Progressive Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/PerpetualEscape_RootsOfMankind_Full.zip']},
#  {'track_id': 'PerpetualEscape_SinSix',
#   'track_name': "'Sin Six'",
#   'artist': 'Perpetual Escape',
#   'genre': 'Progressive Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/PerpetualEscape_SinSix_Full.zip']},
#  {'track_id': 'PerpetualEscape_StopAndRise',
#   'track_name': "'Stop And Rise'",
#   'artist': 'Perpetual Escape',
#   'genre': 'Progressive Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/PerpetualEscape_StopAndRise_Full.zip']},
#  {'track_id': 'RebuildTheEvil_BurialOfSilence',
#   'track_name': "'Burial Of Silence'",
#   'artist': 'Rebuild The Evil',
#   'genre': 'Groove Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/RebuildTheEvil_BurialOfSilence_Full.zip']},
#  {'track_id': 'RobertHammon_TheElephant',
#   'track_name': "'The Elephant'",
#   'artist': 'Robert Hammon',
#   'genre': 'Melodic Emo Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/RobertHammon_TheElephant_Full.zip']},
#  {'track_id': 'RubyRoads_RatRace',
#   'track_name': "'Rat Race'",
#   'artist': 'Ruby Roads',
#   'genre': 'Melodic Hard Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/RubyRoads_RatRace_Full.zip']},
#  {'track_id': 'ScottElliott_AeternumVale',
#   'track_name': "'Aeternum Vale'",
#   'artist': 'Scott Elliott',
#   'genre': 'Cinematic Metal Instrumental',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/ScottElliott_AeternumVale_Full.zip']},
#  {'track_id': 'SilenceIsNear_TheForthcomingTurn',
#   'track_name': "'The Forthcoming Turn'",
#   'artist': 'Silence Is Near',
#   'genre': 'Progressive Death Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/SilenceIsNear_TheForthcomingTurn_Full.zip']},
#  {'track_id': 'StormOfParticles_OfIceAndHopelessFate',
#   'track_name': "'Of Ice And Hopeless Fate'",
#   'artist': 'Storm Of Particles',
#   'genre': 'Melodic Death Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/StormOfParticles_OfIceAndHopelessFate_Full.zip']},
#  {'track_id': 'StreetNoise_IdRatherBeDrinkin',
#   'track_name': "'I'd Rather Be Drinkin''",
#   'artist': 'Street Noise',
#   'genre': 'Various Styles',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/StreetNoise_IdRatherBeDrinkin_Full.zip']},
#  {'track_id': 'StreetNoise_Revelations',
#   'track_name': "'Revelations'",
#   'artist': 'Street Noise',
#   'genre': 'Various Styles',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/StreetNoise_Revelations_Full.zip']},
#  {'track_id': 'StreetNoise_YouAreTheOne',
#   'track_name': "'You Are The One'",
#   'artist': 'Street Noise',
#   'genre': 'Various Styles',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK008/StreetNoise_YouAreTheOne_Full.zip']},
#  {'track_id': 'SzymonSkiba_DeathMetalSucks',
#   'track_name': "'Death Metal Sucks'",
#   'artist': 'Szymon Skiba',
#   'genre': 'Metal Instrumental',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/SzymonSkiba_DeathMetalSucks_Full.zip']},
#  {'track_id': 'SzymonSkiba_LetsDance',
#   'track_name': "'Let's Dance'",
#   'artist': 'Szymon Skiba',
#   'genre': 'Metal Instrumental',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/SzymonSkiba_LetsDance_Full.zip']},
#  {'track_id': 'SzymonSkiba_SomeTrashyThrashIGuess',
#   'track_name': "'Some Trashy Thrash, I Guess'",
#   'artist': 'Szymon Skiba',
#   'genre': 'Metal Instrumental',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK014/SzymonSkiba_SomeTrashyThrashIGuess_Full.zip']},
#  {'track_id': 'Timboz_Pony',
#   'track_name': "'Pony'",
#   'artist': 'Timboz',
#   'genre': 'Screamo Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/Timboz_Pony_Full.zip']},
#  {'track_id': 'Titanium_HauntedAge',
#   'track_name': "'Haunted Age'",
#   'artist': 'Titanium',
#   'genre': 'Black Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/Titanium_HauntedAge_Full.zip']},
#  {'track_id': 'Trafficker_MyFatherNeverLovedMe',
#   'track_name': "'My Father Never Loved Me'",
#   'artist': 'Trafficker',
#   'genre': 'Blues Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/Trafficker_MyFatherNeverLovedMe_Full.zip']},
#  {'track_id': 'Turbosauro_Magilla',
#   'track_name': "'Magilla'",
#   'artist': 'Turbosauro',
#   'genre': 'Progressive Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/Turbosauro_Magilla_Full.zip']},
#  {'track_id': 'UnicornRodeo_Maybe',
#   'track_name': "'Maybe'",
#   'artist': 'Unicorn Rodeo',
#   'genre': 'Melodic Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/UnicornRodeo_Maybe_Full.zip']},
#  {'track_id': 'VMGY_AureusNecrosis',
#   'track_name': "'Aureus Necrosis'",
#   'artist': 'V.M.GY',
#   'genre': 'Progressive Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/VMGY_AureusNecrosis_Full.zip']},
#  {'track_id': 'VMGY_Bloodshed',
#   'track_name': "NEW!\n'Bloodshed'",
#   'artist': 'V.M.GY',
#   'genre': 'Progressive Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/VMGY_Bloodshed_Full.zip']},
#  {'track_id': 'VMGY_Omen',
#   'track_name': "'Omen'",
#   'artist': 'V.M.GY',
#   'genre': 'Progressive Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/VMGY_Omen_Full.zip']},
#  {'track_id': 'Voelund_ComfortLivesInBelief',
#   'track_name': "'Comfort Lives In Belief'",
#   'artist': 'Voelund',
#   'genre': 'Laid-Back Blues-Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK007/Voelund_ComfortLivesInBelief_Full.zip']},
#  {'track_id': 'WallOfDeath_Femme',
#   'track_name': "'Femme'",
#   'artist': 'Wall Of Death',
#   'genre': 'Black Metal',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK009/WallOfDeath_Femme_Full.zip']},
#  {'track_id': 'MR1105_WeFellFromTheSky',
#   'track_name': "'Not You'",
#   'artist': 'We Fell From The Sky',
#   'genre': 'High-Energy Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK003/MR1105_WeFellFromTheSky_Full.zip']},
#  {'track_id': 'Wires_RedOnYou',
#   'track_name': "'Red On You'",
#   'artist': 'Wires',
#   'genre': 'Metalcore',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://multitracks.cambridge-mt.com/Wires_RedOnYou_Full.zip']},
#  {'track_id': 'YoungGriffo_BloodToBone',
#   'track_name': "'Blood To Bone'",
#   'artist': 'Young Griffo',
#   'genre': 'Anthemic Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/YoungGriffo_BloodToBone_Full.zip']},
#  {'track_id': 'MR1110_YoungGriffo',
#   'track_name': "'Facade'",
#   'artist': 'Young Griffo',
#   'genre': 'Anthemic Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR1110_YoungGriffo_Full.zip']},
#  {'track_id': 'YoungGriffo_Pennies',
#   'track_name': "'Pennies'",
#   'artist': 'Young Griffo',
#   'genre': 'Anthemic Heavy Rock',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/YoungGriffo_Pennies_Full.zip']},
#  {'track_id': 'ZaneCarneyAndFriends_TalkToMeBaby',
#   'track_name': "'Talk To Me Baby'",
#   'artist': 'Zane Carney & Friends',
#   'genre': 'Classic Rock Ballad',
#   'category': 'Rock / Punk / Metal',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/ZaneCarneyAndFriends_TalkToMeBaby_Full.zip']},
#  {'track_id': 'AdmiralCrumple_KeepsFlowing',
#   'track_name': "'Keeps Flowing'",
#   'artist': 'Admiral Crumple',
#   'genre': 'Dark Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK005/AdmiralCrumple_KeepsFlowing_Full.zip']},
#  {'track_id': 'AllenStone_Naturally',
#   'track_name': "'Naturally'",
#   'artist': 'Allen Stone',
#   'genre': 'Soul/R&B',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/AllenStone_Naturally_Full.zip']},
#  {'track_id': 'EgdaCarolyn_SaudadeDoTeuBeijo',
#   'track_name': "'Saudade Do Teu Beijo'",
#   'artist': 'Egda Carolyn',
#   'genre': 'Brazilian R&B',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://multitracks.cambridge-mt.com/EgdaCarolyn_SaudadeDoTeuBeijo_Full.zip']},
#  {'track_id': 'JessicaChildress_SlowDown',
#   'track_name': "'Slow Down'",
#   'artist': 'Jessica Childress',
#   'genre': 'Classic R&B',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/JessicaChildress_SlowDown_Full.zip']},
#  {'track_id': 'JustinMyles_AloneWithYou',
#   'track_name': "'Alone With You'",
#   'artist': 'Justin Myles',
#   'genre': 'Smooth R&B',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://multitracks.cambridge-mt.com/JustinMyles_AloneWithYou_Full.zip']},
#  {'track_id': 'Kangoro_Animal',
#   'track_name': "'Animal'",
#   'artist': 'Kangoro',
#   'genre': 'UK Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_Animal_Full.zip']},
#  {'track_id': 'Kangoro_BitchIsParanoid',
#   'track_name': "'Bitch Is Paranoid'",
#   'artist': 'Kangoro',
#   'genre': 'UK Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_BitchIsParanoid_Full.zip']},
#  {'track_id': 'Kangoro_ClinicA',
#   'track_name': "'Clinic A'",
#   'artist': 'Kangoro',
#   'genre': 'UK Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_ClinicA_Full.zip']},
#  {'track_id': 'Kangoro_EasyTiger',
#   'track_name': "'Easy Tiger'",
#   'artist': 'Kangoro',
#   'genre': 'UK Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_EasyTiger_Full.zip']},
#  {'track_id': 'Kangoro_KingRascal',
#   'track_name': "'King Rascal'",
#   'artist': 'Kangoro',
#   'genre': 'UK Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_KingRascal_Full.zip']},
#  {'track_id': 'Kangoro_Rockshow',
#   'track_name': "'Rockshow'",
#   'artist': 'Kangoro',
#   'genre': 'UK Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_Rockshow_Full.zip']},
#  {'track_id': 'KillaL_Window',
#   'track_name': "'Window'",
#   'artist': 'Killa-L',
#   'genre': 'Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK016/KillaL_Window_Full.zip']},
#  {'track_id': 'LittleChicagosFinest_MyOwn',
#   'track_name': "'My Own'",
#   'artist': "Little Chicago's Finest",
#   'genre': 'Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK006/LittleChicagosFinest_MyOwn_Full.zip']},
#  {'track_id': 'MERCMusic_Knockout',
#   'track_name': "'Knockout'",
#   'artist': 'M.E.R.C. Music',
#   'genre': 'Mainstream Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MERCMusic_Knockout_Full.zip']},
#  {'track_id': 'Pepelpovetru_Tochka',
#   'track_name': "'Tochka'",
#   'artist': 'Pepelpovetru',
#   'genre': 'Russian-language Hip-Hop/Rock',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK015/Pepelpovetru_Tochka_Full.zip']},
#  {'track_id': 'RyanCali_BackDown',
#   'track_name': "'Back Down'",
#   'artist': 'Ryan Cali',
#   'genre': 'West-coast Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://multitracks.cambridge-mt.com/RyanCali_BackDown_Full.zip']},
#  {'track_id': 'MR1002_SideEffectsProject',
#   'track_name': "'Sing With Me'",
#   'artist': 'Side Effects Project',
#   'genre': 'West-Coast Hip-Hop',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR1002_SideEffectsProject_Full.zip']},
#  {'track_id': 'MR1002_SideEffectsProject',
#   'track_name': "'Mystery'",
#   'artist': 'Sound On Sound Demo',
#   'genre': 'Hip-Hop/R&B',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR1002_SideEffectsProject_Full.zip']},
#  {'track_id': 'WestEndBlend_KaneGuru',
#   'track_name': "'Kane Guru'",
#   'artist': 'West End Blend',
#   'genre': 'Soul/Funk',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/WestEndBlend_KaneGuru_Full.zip']},
#  {'track_id': 'WestEndBlend_MustBeVoodoo',
#   'track_name': "'Must Be Voodoo'",
#   'artist': 'West End Blend',
#   'genre': 'Soul/Funk',
#   'category': 'Hip-Hop / R&B',
#   'urls': ['https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/WestEndBlend_MustBeVoodoo_Full.zip']}]

# %%
with open('metadata.json', 'w') as f:
    json.dump(metadata, f)

# %%
NUM_RETRIES = 3

def download_file(item):
    track_id, url = item
    extract_dir = os.path.join('download', track_id)
    os.makedirs(extract_dir, exist_ok=True)

    for _ in range(NUM_RETRIES):
        try:
            req = urllib.request.Request(url, headers=HTTP_HEADERS)
            with urllib.request.urlopen(req) as response:
                with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
                    for name in zf.namelist():
                        if os.path.exists(os.path.join(extract_dir, name)):
                            warnings.warn(f'Overwriting {name} from {track_id}')
                    zf.extractall(path=extract_dir)
            return (item, True)
        except:
            traceback.print_exc()
            time.sleep(60)
            
    warnings.warn(f'Failed url: {url} track_id: {track_id}')
    return (item, False)

items = [(item['track_id'], url) for item in metadata for url in item['urls']]
with cf.ProcessPoolExecutor(15) as pool:
    result = list(tqdm(pool.map(download_file, items), total=len(items)))

print('{} / {} files downloaded and extracted successfully'
      .format(sum(success for _, success in result), len(items)), file=sys.stderr)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=438.0), HTML(value='')))
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(278313814 bytes read, 168986639 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(10539844 bytes read, 340217363 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(268778414 bytes read, 130171778 more expected)
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/ from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/01_Bass DI.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/02_BassMic1.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/03_BassMic2.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/04_AcGtr.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/05_AcGtrReampClose.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/06_AcGtrReampFar.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/07_Accordian.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/08_PedalSteel.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/09_LeadVox.wav from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting WesleyMorgan_FleshAndBone_Full/Readme.txt from WesleyMorgan_FleshAndBone
#   from ipykernel import kernelapp as app
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(205032034 bytes read, 154936933 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(72493234 bytes read, 461064475 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(101484454 bytes read, 270185840 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(241826954 bytes read, 325012554 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(341410634 bytes read, 298077245 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(217478394 bytes read, 76518869 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
# Traceback (most recent call last):
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
# http.client.IncompleteRead: IncompleteRead(350696234 bytes read, 352837150 more expected)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(277293274 bytes read, 24920359 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(524338414 bytes read, 74987343 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(453166194 bytes read, 268990905 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(1100949353 bytes read, 59090129 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(1421968313 bytes read, 2379603 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(248452582 bytes read, 501838891 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
# Traceback (most recent call last):
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522:
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK015/JuanitaDientesVerdes_DondeNoLlegaLaLuz_Full.zip track_id: JuanitaDientesVerdes_DondeNoLlegaLaLuz
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK015/JuanitaDientesVerdes_PlacidoDomingo_Full.zip track_id: JuanitaDientesVerdes_PlacidoDomingo
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK001/MR1101_JohnnyLokke_Full.zip track_id: MR1101_JohnnyLokke
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK015/GBassProject_YouMakeMeSmile_Full.zip track_id: GBassProject_YouMakeMeSmile
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK015/JuanitaDientesVerdes_DiosSalveElRockAndRollCieloSinSantos_Full.zip track_id: JuanitaDientesVerdes_DiosSalveElRockAndRollCieloSinSantos
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK008/Forkupines_SleepByTheFireBloomInWater_Full.zip track_id: Forkupines_SleepByTheFireBloomInWater
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK001/JohnnyLokke_WhisperToAScream_Full.zip track_id: JohnnyLokke_WhisperToAScream
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK014/JetB_SuitYou_Full.zip track_id: JetB_SuitYou
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK008/DarkRide_HammerDown_Full.zip track_id: DarkRide_HammerDown
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Fytakyte_Bitter_Full.zip track_id: Fytakyte_Bitter
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK002/TrafficExperiment_OnceMore_Full.zip track_id: TrafficExperiment_OnceMore
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK002/HollowGround_IllFate_Full.zip track_id: HollowGround_IllFate
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK006/ImpossibleColours_DuneRider_Full.zip track_id: ImpossibleColours_DuneRider
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/SixFoxWhiskey_HopeAndTheSea_Full.zip track_id: SixFoxWhiskey_HopeAndTheSea
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
# ...
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Fytakyte_OutaControl_Full.zip track_id: Fytakyte_OutaControl
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(934047993 bytes read, 228262837 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(306060973 bytes read, 824747319 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(253458634 bytes read, 160947390 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(407875674 bytes read, 100536810 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(332977674 bytes read, 537745232 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(391796554 bytes read, 22609470 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 521: Origin Down
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 521: Origin Down
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 521: Origin Down
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 521: Origin Down
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 521: Origin Down
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(16017514 bytes read, 398388510 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(16981114 bytes read, 397424910 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(7713182 bytes read, 500699302 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(13394045 bytes read, 1117414247 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(364722313 bytes read, 797588517 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(14796954 bytes read, 855925952 more expected)
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR1002_SideEffectsProject_Full.zip track_id: MR1002_SideEffectsProject
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK002/MR1002_SideEffectsProject_Full.zip track_id: MR1002_SideEffectsProject
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/JessicaChildress_SlowDown_Full.zip track_id: JessicaChildress_SlowDown
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/WestEndBlend_KaneGuru_Full.zip track_id: WestEndBlend_KaneGuru
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_ClinicA_Full.zip track_id: Kangoro_ClinicA
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/Telefunken/WestEndBlend_MustBeVoodoo_Full.zip track_id: WestEndBlend_MustBeVoodoo
# 417 / 438 files downloaded and extracted successfully

# %%
# Some downloads have failed, let's retry

items = [item for item, success in result if not success]
print(f'Retrying {len(items)} files', file=sys.stderr)
with cf.ProcessPoolExecutor(15) as pool:
    result2 = list(tqdm(pool.map(download_file, items), total=len(items)))

print('{} / {} files downloaded and extracted successfully'
      .format(sum(success for _, success in result2), len(items)), file=sys.stderr)
# Out:
# Retrying 21 files
# HBox(children=(FloatProgress(value=0.0, max=21.0), HTML(value='')))
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/ from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/01_Kick.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/02_Snare1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/03_Snare2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/04_Clap1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/05_Clap2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/06_Clap3.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/07_Clap4.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/08_HiHat1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/09_HiHat2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/10_HiHat3.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/11_HiHat4.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/12_Bongo.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/13_Timbale.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/14_TomRim.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/15_LowTom.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/16_ReverseCymbal.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/17_Shaker.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/18_Bass.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/19_Harp.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/20_SynthLead.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/21_ElecGtrLoop.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/22_Sample1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/23_Sample2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/24_Sample3.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/25_Sample4.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/26_Sample5.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/27_LeadVox1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/28_LeadVox2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/29_LeadVoxDT1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/30_LeadVoxDT2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/31_LeadVoxCh1.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/32_LeadVoxCh2.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/33_LeadVoxCh3.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/34_LeadVoxCh4.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/35_BackingVox01.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/36_BackingVox02.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/37_BackingVox03.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/38_BackingVox04.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/39_BackingVox05.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/40_BackingVox06.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/41_BackingVox07.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/42_BackingVox08.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/43_BackingVox09.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/44_BackingVox10.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/45_BackingVox11.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/46_BackingVox12.wav from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:15: UserWarning: Overwriting MR1002_SideEffectsProject_Full/Readme.txt from MR1002_SideEffectsProject
#   from ipykernel import kernelapp as app
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(450580674 bytes read, 420142232 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(984293753 bytes read, 175745729 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(313880873 bytes read, 816927419 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(611571813 bytes read, 812776103 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(278868613 bytes read, 883442217 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(584341494 bytes read, 119191890 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(533342234 bytes read, 106145645 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 11, in download_file
#     with urllib.request.urlopen(req) as response:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 222, in urlopen
#     return opener.open(url, data, timeout)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 531, in open
#     response = meth(req, response)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 641, in http_response
#     'http', request, response, code, msg, hdrs)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 569, in error
#     return self._call_chain(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 503, in _call_chain
#     result = func(*args)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/urllib/request.py", line 649, in http_error_default
#     raise HTTPError(req.full_url, code, msg, hdrs, fp)
# urllib.error.HTTPError: HTTP Error 522: Origin Connection Time-out
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(40685674 bytes read, 830037232 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(31630753 bytes read, 1128408729 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(85957354 bytes read, 617576030 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(99865314 bytes read, 539622565 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(107431033 bytes read, 1054879797 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(71649353 bytes read, 1352698563 more expected)
# Traceback (most recent call last):
#   File "<ipython-input-7-dc8c99107ec1>", line 12, in download_file
#     with zipfile.ZipFile(io.BytesIO(response.read())) as zf:
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 470, in read
#     s = self._safe_read(self.length)
#   File "/tsi/doctorants/ocifka/envs/nst/lib/python3.7/http/client.py", line 622, in _safe_read
#     raise IncompleteRead(b''.join(s), amt)
# http.client.IncompleteRead: IncompleteRead(28021641 bytes read, 1102786651 more expected)
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK016/Kangoro_ClinicA_Full.zip track_id: Kangoro_ClinicA
# /tsi/doctorants/ocifka/envs/nst/lib/python3.7/site-packages/ipykernel_launcher.py:22: UserWarning: Failed url: https://mtkdata.cambridgemusictechnology.co.uk/MTK002/TrafficExperiment_OnceMore_Full.zip track_id: TrafficExperiment_OnceMore
# 19 / 21 files downloaded and extracted successfully

# %%
# Some downloads have failed for the second time, let's retry again

items = [item for item, success in result2 if not success]
print(f'Retrying {len(items)} files', file=sys.stderr)
with cf.ProcessPoolExecutor(15) as pool:
    result3 = list(tqdm(pool.map(download_file, items), total=len(items)))

print('{} / {} files downloaded and extracted successfully'
      .format(sum(success for _, success in result3), len(items)), file=sys.stderr)
# Out:
# Retrying 2 files
# HBox(children=(FloatProgress(value=0.0, max=2.0), HTML(value='')))
# 2 / 2 files downloaded and extracted successfully

# %%
# Now we should have all 438 files
